# %% [markdown]
# <a href="https://colab.research.google.com/github/Quiago/dlt-course/blob/main/Lesson_3_Pagination_%26_Authentication_%26_dlt_Configuration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Recap of [Lesson 2](https://colab.research.google.com/drive/1tc94GvIoYXmYrjUibDhY_9iPR5zA0Eyw?usp=sharing) 👩‍💻🚀**
#
# 1.  Used `@dlt.resource` to load and query data like lists, dataframes, and REST API responses into DuckDB.
# 2.  Grouped multiple resources into a single `@dlt.source` for better organization and efficiency.
# 3.  Used `@dlt.transformer` to process and enrich data between resources.
#
# Next: Dive deeper into building dlt pipelines using pagination, authentication and dlt configuration! 🚀

# %% [markdown]
# ---
#
# # **Pagination & Authentication & dlt Configuration** 🤫🔩
#
# **Here, you will learn how to:**
# - Use pagination for RestAPIs.
# - Use environment variables to handle both secrets & configs.
# - Add values to `secrets.toml` or `config.toml`.
#
# To read more about credentails refer to [dlt documentation](https://dlthub.com/docs/general-usage/credentials/) here.

# %% [markdown]
# In previous lesson we loaded data from GitHub API  to DuckDB,

# %%
# %%capture
# !pip install dlt

# %%
import dlt
from dlt.sources.helpers import requests


# define dlt resources
@dlt.resource
def github_events():
    url = "https://api.github.com/orgs/dlt-hub/events"
    response = requests.get(url)
    yield response.json()


# define dlt pipeline
pipeline = dlt.pipeline(destination="duckdb")

# run dlt pipeline
load_info = pipeline.run(github_events)
print(load_info)

# explore loaded data
pipeline.dataset(dataset_type="default").github_events.df()
# Out:
# Pipeline dlt_colab_kernel_launcher load step completed in 3.24 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset dlt_colab_kernel_launcher_dataset
# The duckdb destination used duckdb:////content/dlt_colab_kernel_launcher.duckdb location to store data
# Load package 1735782153.646584 is LOADED and contains no failed jobs
#              id               type  actor__id               actor__login  \
# 0   45195652080  IssueCommentEvent   40209326               netlify[bot]
# 1   45195650003   PullRequestEvent   17202864                   rudolfix
# 2   45195641032        CreateEvent   17202864                   rudolfix
# 3   45194550544  IssueCommentEvent   40209326               netlify[bot]
# 4   45194534976   PullRequestEvent   17202864                   rudolfix
# 5   45194516585        CreateEvent   17202864                   rudolfix
# 6   45191608431         WatchEvent   26556793                      KnudH
# 7   45191565131         WatchEvent   85449032                   mjidinio
# 8   45189713148         WatchEvent   43386707                StuffbyYuki
# 9   45189591739  IssueCommentEvent   40209326               netlify[bot]
# 10  45189589077   PullRequestEvent   98139823                  dat-a-man
# 11  45189583089          PushEvent   98139823                  dat-a-man
# 12  45189274152        CreateEvent   98139823                  dat-a-man
# 13  45189265531        DeleteEvent   98139823                  dat-a-man
# 14  45188662374         WatchEvent   34012548                  birdup000
# 15  45186406149         WatchEvent    8856864                 RayyanRiaz
# 16  45186385101         WatchEvent   10522134                tiagotcunha
# 17  45185840489         WatchEvent    5267505                     notyal
# 18  45185654644         WatchEvent   71836523                     Xyndra
# 19  45179837283         WatchEvent   56037939               HenrikThoroe
# 20  45179188141         WatchEvent   57952190             SyedUmairCodes
# 21  45178082970         WatchEvent   52704137                  Tom-Fynes
# 22  45173439556         WatchEvent  185206556  miguelperedozurcher-neste
# 23  45173328311         WatchEvent   17739025            MayankSharma-MS
# 24  45167764356         WatchEvent   67642505                brunomozaki
# 25  45167027631         WatchEvent  102953522                 arjunanan6
# 26  45166820053         WatchEvent   23237149                   Luck1ess
# 27  45164763820         WatchEvent  135314906          CaioCavalcantiRTL
# 28  45163261442          ForkEvent  121238257                abeltavares
# 29  45161447856         WatchEvent  121238257                abeltavares
#
#          actor__display_login actor__gravatar_id  \
# 0                     netlify
# 1                    rudolfix
# 2                    rudolfix
# 3                     netlify
# 4                    rudolfix
# 5                    rudolfix
# 6                       KnudH
# 7                    mjidinio
# 8                 StuffbyYuki
# 9                     netlify
# 10                  dat-a-man
# 11                  dat-a-man
# 12                  dat-a-man
# 13                  dat-a-man
# 14                  birdup000
# 15                 RayyanRiaz
# 16                tiagotcunha
# 17                     notyal
# 18                     Xyndra
# 19               HenrikThoroe
# 20             SyedUmairCodes
# 21                  Tom-Fynes
# 22  miguelperedozurcher-neste
# 23            MayankSharma-MS
# 24                brunomozaki
# 25                 arjunanan6
# 26                   Luck1ess
# 27          CaioCavalcantiRTL
# 28                abeltavares
# 29                abeltavares
#
#                                            actor__url  \
# 0           https://api.github.com/users/netlify[bot]
# 1               https://api.github.com/users/rudolfix
# 2               https://api.github.com/users/rudolfix
# 3           https://api.github.com/users/netlify[bot]
# 4               https://api.github.com/users/rudolfix
# 5               https://api.github.com/users/rudolfix
# 6                  https://api.github.com/users/KnudH
# 7               https://api.github.com/users/mjidinio
# 8            https://api.github.com/users/StuffbyYuki
# 9           https://api.github.com/users/netlify[bot]
# 10             https://api.github.com/users/dat-a-man
# 11             https://api.github.com/users/dat-a-man
# 12             https://api.github.com/users/dat-a-man
# 13             https://api.github.com/users/dat-a-man
# 14             https://api.github.com/users/birdup000
# 15            https://api.github.com/users/RayyanRiaz
# 16           https://api.github.com/users/tiagotcunha
# 17                https://api.github.com/users/notyal
# 18                https://api.github.com/users/Xyndra
# 19          https://api.github.com/users/HenrikThoroe
# 20        https://api.github.com/users/SyedUmairCodes
# 21             https://api.github.com/users/Tom-Fynes
# 22  https://api.github.com/users/miguelperedozurch...
# 23       https://api.github.com/users/MayankSharma-MS
# 24           https://api.github.com/users/brunomozaki
# 25            https://api.github.com/users/arjunanan6
# 26              https://api.github.com/users/Luck1ess
# 27     https://api.github.com/users/CaioCavalcantiRTL
# 28           https://api.github.com/users/abeltavares
# 29           https://api.github.com/users/abeltavares
#
#                                     actor__avatar_url   repo__id  \
# 0   https://avatars.githubusercontent.com/u/40209326?  452221115
# 1   https://avatars.githubusercontent.com/u/17202864?  452221115
# 2   https://avatars.githubusercontent.com/u/17202864?  452221115
# 3   https://avatars.githubusercontent.com/u/40209326?  452221115
# 4   https://avatars.githubusercontent.com/u/17202864?  452221115
# 5   https://avatars.githubusercontent.com/u/17202864?  452221115
# 6   https://avatars.githubusercontent.com/u/26556793?  452221115
# 7   https://avatars.githubusercontent.com/u/85449032?  817187285
# 8   https://avatars.githubusercontent.com/u/43386707?  817187285
# 9   https://avatars.githubusercontent.com/u/40209326?  452221115
# 10  https://avatars.githubusercontent.com/u/98139823?  452221115
# 11  https://avatars.githubusercontent.com/u/98139823?  452221115
# 12  https://avatars.githubusercontent.com/u/98139823?  452221115
# 13  https://avatars.githubusercontent.com/u/98139823?  452221115
# 14  https://avatars.githubusercontent.com/u/34012548?  452221115
# 15   https://avatars.githubusercontent.com/u/8856864?  452221115
# 16  https://avatars.githubusercontent.com/u/10522134?  688593654
# 17   https://avatars.githubusercontent.com/u/5267505?  452221115
# 18  https://avatars.githubusercontent.com/u/71836523?  452221115
# 19  https://avatars.githubusercontent.com/u/56037939?  452221115
# 20  https://avatars.githubusercontent.com/u/57952190?  452221115
# 21  https://avatars.githubusercontent.com/u/52704137?  452221115
# 22  https://avatars.githubusercontent.com/u/185206...  452221115
# 23  https://avatars.githubusercontent.com/u/17739025?  452221115
# 24  https://avatars.githubusercontent.com/u/67642505?  817187285
# 25  https://avatars.githubusercontent.com/u/102953...  817187285
# 26  https://avatars.githubusercontent.com/u/23237149?  452221115
# 27  https://avatars.githubusercontent.com/u/135314...  452221115
# 28  https://avatars.githubusercontent.com/u/121238...  452221115
# 29  https://avatars.githubusercontent.com/u/121238...  452221115
#
#                   repo__name  ... payload__forkee__open_issues_count  \
# 0                dlt-hub/dlt  ...                                NaN
# 1                dlt-hub/dlt  ...                                NaN
# 2                dlt-hub/dlt  ...                                NaN
# 3                dlt-hub/dlt  ...                                NaN
# 4                dlt-hub/dlt  ...                                NaN
# 5                dlt-hub/dlt  ...                                NaN
# 6                dlt-hub/dlt  ...                                NaN
# 7   dlt-hub/dlthub-education  ...                                NaN
# 8   dlt-hub/dlthub-education  ...                                NaN
# 9                dlt-hub/dlt  ...                                NaN
# 10               dlt-hub/dlt  ...                                NaN
# 11               dlt-hub/dlt  ...                                NaN
# 12               dlt-hub/dlt  ...                                NaN
# 13               dlt-hub/dlt  ...                                NaN
# 14               dlt-hub/dlt  ...                                NaN
# 15               dlt-hub/dlt  ...                                NaN
# 16         dlt-hub/dlt_demos  ...                                NaN
# 17               dlt-hub/dlt  ...                                NaN
# 18               dlt-hub/dlt  ...                                NaN
# 19               dlt-hub/dlt  ...                                NaN
# 20               dlt-hub/dlt  ...                                NaN
# 21               dlt-hub/dlt  ...                                NaN
# 22               dlt-hub/dlt  ...                                NaN
# 23               dlt-hub/dlt  ...                                NaN
# 24  dlt-hub/dlthub-education  ...                                NaN
# 25  dlt-hub/dlthub-education  ...                                NaN
# 26               dlt-hub/dlt  ...                                NaN
# 27               dlt-hub/dlt  ...                                NaN
# 28               dlt-hub/dlt  ...                                0.0
# 29               dlt-hub/dlt  ...                                NaN
#
#    payload__forkee__allow_forking payload__forkee__is_template  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
# 5                             NaN                          NaN
# 6                             NaN                          NaN
# 7                             NaN                          NaN
# 8                             NaN                          NaN
# 9                             NaN                          NaN
# 10                            NaN                          NaN
# 11                            NaN                          NaN
# 12                            NaN                          NaN
# 13                            NaN                          NaN
# 14                            NaN                          NaN
# 15                            NaN                          NaN
# 16                            NaN                          NaN
# 17                            NaN                          NaN
# 18                            NaN                          NaN
# 19                            NaN                          NaN
# 20                            NaN                          NaN
# 21                            NaN                          NaN
# 22                            NaN                          NaN
# 23                            NaN                          NaN
# 24                            NaN                          NaN
# 25                            NaN                          NaN
# 26                            NaN                          NaN
# 27                            NaN                          NaN
# 28                           True                        False
# 29                            NaN                          NaN
#
#    payload__forkee__web_commit_signoff_required payload__forkee__visibility  \
# 0                                           NaN                        None
# 1                                           NaN                        None
# 2                                           NaN                        None
# 3                                           NaN                        None
# 4                                           NaN                        None
# 5                                           NaN                        None
# 6                                           NaN                        None
# 7                                           NaN                        None
# 8                                           NaN                        None
# 9                                           NaN                        None
# 10                                          NaN                        None
# 11                                          NaN                        None
# 12                                          NaN                        None
# 13                                          NaN                        None
# 14                                          NaN                        None
# 15                                          NaN                        None
# 16                                          NaN                        None
# 17                                          NaN                        None
# 18                                          NaN                        None
# 19                                          NaN                        None
# 20                                          NaN                        None
# 21                                          NaN                        None
# 22                                          NaN                        None
# 23                                          NaN                        None
# 24                                          NaN                        None
# 25                                          NaN                        None
# 26                                          NaN                        None
# 27                                          NaN                        None
# 28                                        False                      public
# 29                                          NaN                        None
#
#    payload__forkee__forks payload__forkee__open_issues  \
# 0                     NaN                          NaN
# 1                     NaN                          NaN
# 2                     NaN                          NaN
# 3                     NaN                          NaN
# 4                     NaN                          NaN
# 5                     NaN                          NaN
# 6                     NaN                          NaN
# 7                     NaN                          NaN
# 8                     NaN                          NaN
# 9                     NaN                          NaN
# 10                    NaN                          NaN
# 11                    NaN                          NaN
# 12                    NaN                          NaN
# 13                    NaN                          NaN
# 14                    NaN                          NaN
# 15                    NaN                          NaN
# 16                    NaN                          NaN
# 17                    NaN                          NaN
# 18                    NaN                          NaN
# 19                    NaN                          NaN
# 20                    NaN                          NaN
# 21                    NaN                          NaN
# 22                    NaN                          NaN
# 23                    NaN                          NaN
# 24                    NaN                          NaN
# 25                    NaN                          NaN
# 26                    NaN                          NaN
# 27                    NaN                          NaN
# 28                    0.0                          0.0
# 29                    NaN                          NaN
#
#    payload__forkee__watchers  payload__forkee__default_branch  \
# 0                        NaN                             None
# 1                        NaN                             None
# 2                        NaN                             None
# 3                        NaN                             None
# 4                        NaN                             None
# 5                        NaN                             None
# 6                        NaN                             None
# 7                        NaN                             None
# 8                        NaN                             None
# 9                        NaN                             None
# 10                       NaN                             None
# 11                       NaN                             None
# 12                       NaN                             None
# 13                       NaN                             None
# 14                       NaN                             None
# 15                       NaN                             None
# 16                       NaN                             None
# 17                       NaN                             None
# 18                       NaN                             None
# 19                       NaN                             None
# 20                       NaN                             None
# 21                       NaN                             None
# 22                       NaN                             None
# 23                       NaN                             None
# 24                       NaN                             None
# 25                       NaN                             None
# 26                       NaN                             None
# 27                       NaN                             None
# 28                       0.0                             main
# 29                       NaN                             None
#
#    payload__forkee__public
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27                     NaN
# 28                    True
# 29                     NaN
#
# [30 rows x 552 columns]

# %% [markdown]
# You could notice that we received only 1 page, only 30 records. But this endpoint has muuuch more records in total. To get all the pages you should use a pagination.
#
# When working with APIs like GitHub, data is often returned in pages. Pagination allows you to retrieve all the data when an endpoint limits how much can be fetched at once.

# %% [markdown]
# ![1_D9K_aEWo9MDx7osLKT1Cxw.webp](data:image/webp;base64,...)

# %% [markdown]
# ## **Pagination**
#
# GitHub has very good documentation, so it is not difficult to go through the documentation and find the relevant page: [Pagination.](https://docs.github.com/en/rest/using-the-rest-api/using-pagination-in-the-rest-api?apiVersion=2022-11-28)
#
# It says:
# >You can use the `link` header from the response to request additional pages of data.
#
# >The link header contains URLs that you can use to fetch additional pages of results. For example, the previous, next, first, and last page of results.

# %% [markdown]
# **GitHub API Pagination example**
#
# The GitHub API provides the `per_page` and `page` query parameters:
#
# * `per_page`: The number of records per page (up to 100).
# * `page`: The page number to retrieve.

# %%
import requests
response = requests.get("https://api.github.com/orgs/dlt-hub/events?per_page=10&page=1")
response.headers
# Out:
# {'Date': 'Thu, 02 Jan 2025 01:42:41 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept,Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"d40e1576181dbf0c6357480e54f2bc25e587810fcd6b0ca6f0dd00d77bdf7a53"', 'Last-Modified': 'Wed, 01 Jan 2025 19:40:24 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/organizations/89419010/events?per_page=10&page=2>; rel="next", <https://api.github.com/organizations/89419010/events?per_page=10&page=30>; rel="last"', 'x-github-api-version-selected': '2022-11-28', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'Server': 'github.com', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '59', 'X-RateLimit-Reset': '1735785761', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '1', 'Accept-Ranges': 'bytes', 'Transfer-Encoding': 'chunked', 'X-GitHub-Request-Id': '999C:368A9A:320041:6340EF:6775EF11'}

# %% [markdown]
# Gotcha! We can see 'Link' in the headers. To get this link we can alternatively use `response.links`:

# %%
import requests
response = requests.get("https://api.github.com/orgs/dlt-hub/events?per_page=10&page=1")
response.links
# Out:
# {'next': {'url': 'https://api.github.com/organizations/89419010/events?per_page=10&page=2',
#   'rel': 'next'},
#  'last': {'url': 'https://api.github.com/organizations/89419010/events?per_page=10&page=30',
#   'rel': 'last'}}

# %% [markdown]
# ### **dlt RESTClient**
#
# The response includes a 'Link' header for navigating to the next page.
# So now we can implement a pagination!
#
# When working with APIs, you could implement pagination using only Python and the requests library. While this approach works, it often requires writing boilerplate code for tasks like managing authentication, constructing URLs, and handling pagination logic.
#
# More about how to build pagination with Python and `requests`:
#
# * [Link 1](https://farnamdata.com/api-pagination)
#
# * [Link 2](https://www.klamp.io/blog/python-requests-pagination-for-efficient-data-retrieval)
#
# **But!** In this lesson, we’re gonna use dlt's **[RESTClient](https://dlthub.com/docs/general-usage/http/rest-client)** to handle pagination seamlessly when working with REST APIs like GitHub.
#
#
# **Why use RESTClient?**
#
# RESTClient is part of dlt's helpers, making it easier to interact with REST APIs by managing repetitive tasks such as:
#
# * Authentication
# * Query parameter handling
# * Pagination
#
# This reduces boilerplate code and lets you focus on your data pipeline logic.
#
# **Here’s how to fetch paginated data:**
# 1. Import RESTClient
# 2. Create the RESTClient instance
# 3. Use the `paginate` method to iterate through all pages of data.

# %%
from dlt.sources.helpers.rest_client import RESTClient


client = RESTClient(
    base_url="https://api.github.com",
)

for page in client.paginate("orgs/dlt-hub/events"):
    print(len(page),page)
# Out:
# 30 [{'id': '45195652080', 'type': 'IssueCommentEvent', 'actor': {'id': 40209326, 'login': 'netlify[bot]', 'display_login': 'netlify', 'gravatar_id': '', 'url': 'https://api.github.com/users/netlify[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/40209326?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'created', 'issue': {'url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2184', 'repository_url': 'https://api.github.com/repos/dlt-hub/dlt', 'labels_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2184/labels{/name}', 'comments_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2184/comments', 'events_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2184/events', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2184', 'id': 2765229257, 'node_id': 'PR_kwDOGvRYu86GifWf', 'number': 2184, 'title': 'unifies handling of naive datetime for arrow and object incrementals', 'user': {'login': 'rudolfix', 'id': 17202864, 'node_id': 'MDQ6VXNlcjE3MjAyODY0', 'avatar_url': 'https://avatars.githubusercontent.com/u/17202864?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/rudolfix', 'html_url': 'https://github.com/rudolfix', 'followers_url': 'https://api.github.com/users/rudolfix/followers', 'following_url': 'https://api.github.com/users/rudolfix/following{/other_user}', 'gists_url': 'https://api.github.com/users/rudolfix/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/rudolfix/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/rudolfix/subscriptions', 'organizations_url': 'https://api.github.com/users/rudolfix/orgs', 'repos_url': 'https://api.github.com/users/rudolfix/repos', 'events_url': 'https://api.github.com/users/rudolfix/events{/privacy}', 'received_events_url': 'https://api.github.com/users/rudolfix/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'labels': [], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 1, 'created_at': '2025-01-01T19:40:07Z', 'updated_at': '2025-01-01T19:40:24Z', 'closed_at': None, 'author_association': 'COLLABORATOR', 'active_lock_reason': None, 'draft': True, 'pull_request': {'url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2184', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2184', 'diff_url': 'https://github.com/dlt-hub/dlt/pull/2184.diff', 'patch_url': 'https://github.com/dlt-hub/dlt/pull/2184.patch', 'merged_at': None}, 'body': '<!--\r\nThank you for submitting a pull request! Please provide a brief description of your changes below.\r\n-->\r\n### Description\r\nunifies handling of naive datetime for arrow and object incrementals\r\n', 'reactions': {'url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2184/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'timeline_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2184/timeline', 'performed_via_github_app': None, 'state_reason': None}, 'comment': {'url': 'https://api.github.com/repos/dlt-hub/dlt/issues/comments/2567123477', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2184#issuecomment-2567123477', 'issue_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2184', 'id': 2567123477, 'node_id': 'IC_kwDOGvRYu86ZAzIV', 'user': {'login': 'netlify[bot]', 'id': 40209326, 'node_id': 'MDM6Qm90NDAyMDkzMjY=', 'avatar_url': 'https://avatars.githubusercontent.com/in/13473?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/netlify%5Bbot%5D', 'html_url': 'https://github.com/apps/netlify', 'followers_url': 'https://api.github.com/users/netlify%5Bbot%5D/followers', 'following_url': 'https://api.github.com/users/netlify%5Bbot%5D/following{/other_user}', 'gists_url': 'https://api.github.com/users/netlify%5Bbot%5D/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/netlify%5Bbot%5D/starred{/owner}{/repo}', 'subs ...
# 30 [{'id': '45152471231', 'type': 'WatchEvent', 'actor': {'id': 187031655, 'login': 'kilian-sg', 'display_login': 'kilian-sg', 'gravatar_id': '', 'url': 'https://api.github.com/users/kilian-sg', 'avatar_url': 'https://avatars.githubusercontent.com/u/187031655?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2024-12-30T09:04:57Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '45151633321', 'type': 'WatchEvent', 'actor': {'id': 149126508, 'login': 'meagsp', 'display_login': 'meagsp', 'gravatar_id': '', 'url': 'https://api.github.com/users/meagsp', 'avatar_url': 'https://avatars.githubusercontent.com/u/149126508?'}, 'repo': {'id': 817187285, 'name': 'dlt-hub/dlthub-education', 'url': 'https://api.github.com/repos/dlt-hub/dlthub-education'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2024-12-30T08:19:11Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '45144428161', 'type': 'WatchEvent', 'actor': {'id': 89187645, 'login': 'apd-bscally', 'display_login': 'apd-bscally', 'gravatar_id': '', 'url': 'https://api.github.com/users/apd-bscally', 'avatar_url': 'https://avatars.githubusercontent.com/u/89187645?'}, 'repo': {'id': 817187285, 'name': 'dlt-hub/dlthub-education', 'url': 'https://api.github.com/repos/dlt-hub/dlthub-education'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2024-12-29T20:38:11Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '45144273505', 'type': 'WatchEvent', 'actor': {'id': 89292251, 'login': 'PK109', 'display_login': 'PK109', 'gravatar_id': '', 'url': 'https://api.github.com/users/PK109', 'avatar_url': 'https://avatars.githubusercontent.com/u/89292251?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2024-12-29T20:18:10Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '45142303407', 'type': 'PushEvent', 'actor': {'id': 17202864, 'login': 'rudolfix', 'display_login': 'rudolfix', 'gravatar_id': '', 'url': 'https://api.github.com/users/rudolfix', 'avatar_url': 'https://avatars.githubusercontent.com/u/17202864?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'repository_id': 452221115, 'push_id': 21903089736, 'size': 2, 'distinct_size': 2, 'ref': 'refs/heads/feat/enables-python-3.13', 'head': '31e74b24004f7b982f9d880ae4f30d8d5bb1b3cc', 'before': '986d275951abb70b2b8bc3c979e6212a1495b07b', 'commits': [{'sha': '6ef45c6331fcef08ae5c8e75f05ea1b59125cea9', 'author': {'email': 'rudolfix@rudolfix.org', 'name': 'Marcin Rudolf'}, 'message': 'fixes inserted_at to datetime', 'distinct': True, 'url': 'https://api.github.com/repos/dlt-hub/dlt/commits/6ef45c6331fcef08ae5c8e75f05ea1b59125cea9'}, {'sha': '31e74b24004f7b982f9d880ae4f30d8d5bb1b3cc', 'author': {'email': 'rudolfix@rudolfix.org', 'name': 'Marcin Rudolf'}, 'message': 'ci cache renames', 'distinct': True, 'url': 'https://api.github.com/repos/dlt-hub/dlt/commits/31e74b24004f7b982f9d880ae4f30d8d5bb1b3cc'}]}, 'public': True, 'created_at': '2024-12-29T16:23:37Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '45142003606', 'type': 'WatchEvent', 'act ...
# 30 [{'id': '45116893445', 'type': 'WatchEvent', 'actor': {'id': 6882610, 'login': 'tyrwzl', 'display_login': 'tyrwzl', 'gravatar_id': '', 'url': 'https://api.github.com/users/tyrwzl', 'avatar_url': 'https://avatars.githubusercontent.com/u/6882610?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2024-12-27T15:08:22Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '45112539215', 'type': 'WatchEvent', 'actor': {'id': 20367975, 'login': 'AstrakhantsevaAA', 'display_login': 'AstrakhantsevaAA', 'gravatar_id': '', 'url': 'https://api.github.com/users/AstrakhantsevaAA', 'avatar_url': 'https://avatars.githubusercontent.com/u/20367975?'}, 'repo': {'id': 750283387, 'name': 'dlt-hub/data_engineering_best_practices', 'url': 'https://api.github.com/repos/dlt-hub/data_engineering_best_practices'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2024-12-27T10:59:35Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '45110552618', 'type': 'IssuesEvent', 'actor': {'id': 44533769, 'login': 'korbash', 'display_login': 'korbash', 'gravatar_id': '', 'url': 'https://api.github.com/users/korbash', 'avatar_url': 'https://avatars.githubusercontent.com/u/44533769?'}, 'repo': {'id': 584776311, 'name': 'dlt-hub/verified-sources', 'url': 'https://api.github.com/repos/dlt-hub/verified-sources'}, 'payload': {'action': 'opened', 'issue': {'url': 'https://api.github.com/repos/dlt-hub/verified-sources/issues/591', 'repository_url': 'https://api.github.com/repos/dlt-hub/verified-sources', 'labels_url': 'https://api.github.com/repos/dlt-hub/verified-sources/issues/591/labels{/name}', 'comments_url': 'https://api.github.com/repos/dlt-hub/verified-sources/issues/591/comments', 'events_url': 'https://api.github.com/repos/dlt-hub/verified-sources/issues/591/events', 'html_url': 'https://github.com/dlt-hub/verified-sources/issues/591', 'id': 2760618686, 'node_id': 'I_kwDOItr6d86ki7K-', 'number': 591, 'title': 'in Google Sheets drop column if first value is null', 'user': {'login': 'korbash', 'id': 44533769, 'node_id': 'MDQ6VXNlcjQ0NTMzNzY5', 'avatar_url': 'https://avatars.githubusercontent.com/u/44533769?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/korbash', 'html_url': 'https://github.com/korbash', 'followers_url': 'https://api.github.com/users/korbash/followers', 'following_url': 'https://api.github.com/users/korbash/following{/other_user}', 'gists_url': 'https://api.github.com/users/korbash/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/korbash/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/korbash/subscriptions', 'organizations_url': 'https://api.github.com/users/korbash/orgs', 'repos_url': 'https://api.github.com/users/korbash/repos', 'events_url': 'https://api.github.com/users/korbash/events{/privacy}', 'received_events_url': 'https://api.github.com/users/korbash/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'labels': [], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 0, 'created_at': '2024-12-27T09:10:21Z', 'updated_at': '2024-12-27T09:10:21Z', 'closed_at': None, 'author_association': 'NONE', 'active_lock_reason': None, 'body': '### dlt version\n\n1.4.1\n\n### Source name\n\ngoogle_sheets\n\n### Describe the problem\n\n**Issue:**\r\n\r\nWhen working with this table in Google Sheets:\r\n\r\n| Col0 | Col1 |\r\n|------|------|\r\n| a    |      |\r\n| b    | c    |\r\n\r\nThe second column (`Col1`) droped by source.\r\n\r\n**What should happen:**\r\n\r\nBoth columns (`Col0` and `Col1`) should keep their data  ...
# 30 [{'id': '45066658009', 'type': 'WatchEvent', 'actor': {'id': 14275545, 'login': 'dmschauer', 'display_login': 'dmschauer', 'gravatar_id': '', 'url': 'https://api.github.com/users/dmschauer', 'avatar_url': 'https://avatars.githubusercontent.com/u/14275545?'}, 'repo': {'id': 817187285, 'name': 'dlt-hub/dlthub-education', 'url': 'https://api.github.com/repos/dlt-hub/dlthub-education'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2024-12-24T17:51:10Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '45065870033', 'type': 'WatchEvent', 'actor': {'id': 24478968, 'login': 'matfior', 'display_login': 'matfior', 'gravatar_id': '', 'url': 'https://api.github.com/users/matfior', 'avatar_url': 'https://avatars.githubusercontent.com/u/24478968?'}, 'repo': {'id': 817187285, 'name': 'dlt-hub/dlthub-education', 'url': 'https://api.github.com/repos/dlt-hub/dlthub-education'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2024-12-24T16:51:44Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '45065509710', 'type': 'WatchEvent', 'actor': {'id': 69216650, 'login': 'samvardhan777', 'display_login': 'samvardhan777', 'gravatar_id': '', 'url': 'https://api.github.com/users/samvardhan777', 'avatar_url': 'https://avatars.githubusercontent.com/u/69216650?'}, 'repo': {'id': 817187285, 'name': 'dlt-hub/dlthub-education', 'url': 'https://api.github.com/repos/dlt-hub/dlthub-education'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2024-12-24T16:26:30Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '45054458052', 'type': 'ForkEvent', 'actor': {'id': 122973093, 'login': 'vijaykrishna78', 'display_login': 'vijaykrishna78', 'gravatar_id': '', 'url': 'https://api.github.com/users/vijaykrishna78', 'avatar_url': 'https://avatars.githubusercontent.com/u/122973093?'}, 'repo': {'id': 817187285, 'name': 'dlt-hub/dlthub-education', 'url': 'https://api.github.com/repos/dlt-hub/dlthub-education'}, 'payload': {'forkee': {'id': 907696789, 'node_id': 'R_kgDONhpalQ', 'name': 'dlthub-education', 'full_name': 'vijaykrishna78/dlthub-education', 'private': False, 'owner': {'login': 'vijaykrishna78', 'id': 122973093, 'node_id': 'U_kgDOB1RrpQ', 'avatar_url': 'https://avatars.githubusercontent.com/u/122973093?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/vijaykrishna78', 'html_url': 'https://github.com/vijaykrishna78', 'followers_url': 'https://api.github.com/users/vijaykrishna78/followers', 'following_url': 'https://api.github.com/users/vijaykrishna78/following{/other_user}', 'gists_url': 'https://api.github.com/users/vijaykrishna78/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/vijaykrishna78/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/vijaykrishna78/subscriptions', 'organizations_url': 'https://api.github.com/users/vijaykrishna78/orgs', 'repos_url': 'https://api.github.com/users/vijaykrishna78/repos', 'events_url': 'https://api.github.com/users/vijaykrishna78/events{/privacy}', 'received_events_url': 'https://api.github.com/users/vijaykrishna78/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/vijaykrishna78/dlthub-education', 'description': 'In this repository we will store all materials for workshops, courses, etc.', 'fork': True, 'url': 'https://api.github.com/repos/vijaykrishna78/dlthub-education', 'forks_url': 'https://api.github.com/repos/vijaykrishna78/dlthub-education/forks', 'keys_url': 'https://api.github.com/repos/vijaykrishna78/dlthub-education/keys{/key_id}', 'collabora ...
# 30 [{'id': '45031727384', 'type': 'PullRequestReviewCommentEvent', 'actor': {'id': 17202864, 'login': 'rudolfix', 'display_login': 'rudolfix', 'gravatar_id': '', 'url': 'https://api.github.com/users/rudolfix', 'avatar_url': 'https://avatars.githubusercontent.com/u/17202864?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'created', 'comment': {'url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/comments/1895594245', 'pull_request_review_id': 2520344669, 'id': 1895594245, 'node_id': 'PRRC_kwDOGvRYu85w_HkF', 'diff_hunk': '@@ -135,15 +128,10 @@ def run_dbt_command(\n         runner_args = (global_args or []) + [command] + args  # type: ignore\n \n         with dbt.logger.log_manager.applicationbound():\n-            try:', 'path': 'dlt/helpers/dbt/dbt_utils.py', 'commit_id': 'a0100ce567a2082fc0f75c5e83d76cd311d61c5e', 'original_commit_id': 'a0100ce567a2082fc0f75c5e83d76cd311d61c5e', 'user': {'login': 'rudolfix', 'id': 17202864, 'node_id': 'MDQ6VXNlcjE3MjAyODY0', 'avatar_url': 'https://avatars.githubusercontent.com/u/17202864?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/rudolfix', 'html_url': 'https://github.com/rudolfix', 'followers_url': 'https://api.github.com/users/rudolfix/followers', 'following_url': 'https://api.github.com/users/rudolfix/following{/other_user}', 'gists_url': 'https://api.github.com/users/rudolfix/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/rudolfix/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/rudolfix/subscriptions', 'organizations_url': 'https://api.github.com/users/rudolfix/orgs', 'repos_url': 'https://api.github.com/users/rudolfix/repos', 'events_url': 'https://api.github.com/users/rudolfix/events{/privacy}', 'received_events_url': 'https://api.github.com/users/rudolfix/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'body': 'right! the fact is we do not support <1.5 for a long time already...', 'created_at': '2024-12-23T10:39:13Z', 'updated_at': '2024-12-23T10:39:14Z', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2175#discussion_r1895594245', 'pull_request_url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2175', 'author_association': 'COLLABORATOR', '_links': {'self': {'href': 'https://api.github.com/repos/dlt-hub/dlt/pulls/comments/1895594245'}, 'html': {'href': 'https://github.com/dlt-hub/dlt/pull/2175#discussion_r1895594245'}, 'pull_request': {'href': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2175'}}, 'reactions': {'url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/comments/1895594245/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'start_line': None, 'original_start_line': None, 'start_side': None, 'line': 138, 'original_line': 138, 'side': 'LEFT', 'in_reply_to_id': 1895396596, 'original_position': 33, 'position': 33, 'subject_type': 'line'}, 'pull_request': {'url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2175', 'id': 2248504264, 'node_id': 'PR_kwDOGvRYu86GBXPI', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2175', 'diff_url': 'https://github.com/dlt-hub/dlt/pull/2175.diff', 'patch_url': 'https://github.com/dlt-hub/dlt/pull/2175.patch', 'issue_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2175', 'number': 2175, 'state': 'open', 'locked': False, 'title': '#2020 #2151 - fixes dbt 1.8.6 and arrow dict types', 'user': {'login': 'rudolfix', 'id': 17202864, 'node_id': 'MDQ6VXNlcjE3MjAyODY0', 'avatar_url': 'https://avatars.githubusercontent.com/u/17202864?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/rudolfix', 'html_url': 'https://github.com/rudolfix', 'followers_url': 'https://api.github.com/users/rudolfix/followers', 'following_url': 'https://api.github.com/users/rudolfix/following{/other_user}', 'gists_url': 'https://api.github.com/users/rudolfix/gists{/gist_id}', 'starred_url': 'https://api.g ...
# 30 [{'id': '45018210765', 'type': 'PullRequestReviewEvent', 'actor': {'id': 17202864, 'login': 'rudolfix', 'display_login': 'rudolfix', 'gravatar_id': '', 'url': 'https://api.github.com/users/rudolfix', 'avatar_url': 'https://avatars.githubusercontent.com/u/17202864?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'created', 'review': {'id': 2519686485, 'node_id': 'PRR_kwDOGvRYu86WL11V', 'user': {'login': 'rudolfix', 'id': 17202864, 'node_id': 'MDQ6VXNlcjE3MjAyODY0', 'avatar_url': 'https://avatars.githubusercontent.com/u/17202864?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/rudolfix', 'html_url': 'https://github.com/rudolfix', 'followers_url': 'https://api.github.com/users/rudolfix/followers', 'following_url': 'https://api.github.com/users/rudolfix/following{/other_user}', 'gists_url': 'https://api.github.com/users/rudolfix/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/rudolfix/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/rudolfix/subscriptions', 'organizations_url': 'https://api.github.com/users/rudolfix/orgs', 'repos_url': 'https://api.github.com/users/rudolfix/repos', 'events_url': 'https://api.github.com/users/rudolfix/events{/privacy}', 'received_events_url': 'https://api.github.com/users/rudolfix/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'body': 'thanks for the fix and writing the test! pls see the review comments', 'commit_id': '1877b2d931e5dfd5eda75a9f2109ad3ecdd6281e', 'submitted_at': '2024-12-22T19:49:13Z', 'state': 'changes_requested', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2172#pullrequestreview-2519686485', 'pull_request_url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2172', 'author_association': 'COLLABORATOR', '_links': {'html': {'href': 'https://github.com/dlt-hub/dlt/pull/2172#pullrequestreview-2519686485'}, 'pull_request': {'href': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2172'}}}, 'pull_request': {'url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2172', 'id': 2248196354, 'node_id': 'PR_kwDOGvRYu86GAMEC', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2172', 'diff_url': 'https://github.com/dlt-hub/dlt/pull/2172.diff', 'patch_url': 'https://github.com/dlt-hub/dlt/pull/2172.patch', 'issue_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2172', 'number': 2172, 'state': 'open', 'locked': False, 'title': 'fix: unravel Optional to inner generic arg from instance', 'user': {'login': 'otosky', 'id': 42260747, 'node_id': 'MDQ6VXNlcjQyMjYwNzQ3', 'avatar_url': 'https://avatars.githubusercontent.com/u/42260747?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/otosky', 'html_url': 'https://github.com/otosky', 'followers_url': 'https://api.github.com/users/otosky/followers', 'following_url': 'https://api.github.com/users/otosky/following{/other_user}', 'gists_url': 'https://api.github.com/users/otosky/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/otosky/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/otosky/subscriptions', 'organizations_url': 'https://api.github.com/users/otosky/orgs', 'repos_url': 'https://api.github.com/users/otosky/repos', 'events_url': 'https://api.github.com/users/otosky/events{/privacy}', 'received_events_url': 'https://api.github.com/users/otosky/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'body': '<!--\r\nThank you for submitting a pull request! Please provide a brief description of your changes below.\r\n-->\r\n\r\nAddresses resources created by the `rest_api_resources` factory function exiting prematurely when trying to _join_external_scheduler and not inferring start/end dates from Airflow.\r\n\r\n<!--\r\nPlease link any related issues. This helps us keep the PR focused and merge it faster.\r\n-->\r\n### Related Issues\r\n\r\nCloses #2171 \r\n\r\n<!--\r\nProvide any additional conte ...
# 30 [{'id': '44976791068', 'type': 'PullRequestEvent', 'actor': {'id': 1155738, 'login': 'sh-rp', 'display_login': 'sh-rp', 'gravatar_id': '', 'url': 'https://api.github.com/users/sh-rp', 'avatar_url': 'https://avatars.githubusercontent.com/u/1155738?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'opened', 'number': 2168, 'pull_request': {'url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2168', 'id': 2246397911, 'node_id': 'PR_kwDOGvRYu86F5U_X', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2168', 'diff_url': 'https://github.com/dlt-hub/dlt/pull/2168.diff', 'patch_url': 'https://github.com/dlt-hub/dlt/pull/2168.patch', 'issue_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2168', 'number': 2168, 'state': 'open', 'locked': False, 'title': '[Experiment] extending features with addition pip package', 'user': {'login': 'sh-rp', 'id': 1155738, 'node_id': 'MDQ6VXNlcjExNTU3Mzg=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1155738?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/sh-rp', 'html_url': 'https://github.com/sh-rp', 'followers_url': 'https://api.github.com/users/sh-rp/followers', 'following_url': 'https://api.github.com/users/sh-rp/following{/other_user}', 'gists_url': 'https://api.github.com/users/sh-rp/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/sh-rp/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/sh-rp/subscriptions', 'organizations_url': 'https://api.github.com/users/sh-rp/orgs', 'repos_url': 'https://api.github.com/users/sh-rp/repos', 'events_url': 'https://api.github.com/users/sh-rp/events{/privacy}', 'received_events_url': 'https://api.github.com/users/sh-rp/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'body': '<!--\r\nThank you for submitting a pull request! Please provide a brief description of your changes below.\r\n-->\r\n### Description\r\n\r\nThis example shows how to implement a basic version of a feature in one package and extending it in another package making it possible for the base lib to load the extended version if present. We use a factory for this and this will also allow us to upgrade typing to a new version if a certain lib is present.', 'created_at': '2024-12-20T10:13:09Z', 'updated_at': '2024-12-20T10:13:09Z', 'closed_at': None, 'merged_at': None, 'merge_commit_sha': None, 'assignee': None, 'assignees': [], 'requested_reviewers': [], 'requested_teams': [], 'labels': [], 'milestone': None, 'draft': True, 'commits_url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2168/commits', 'review_comments_url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2168/comments', 'review_comment_url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/comments{/number}', 'comments_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2168/comments', 'statuses_url': 'https://api.github.com/repos/dlt-hub/dlt/statuses/eb51f2ec35acbb873fe17f9508897f7146e07694', 'head': {'label': 'dlt-hub:exp/extending_features', 'ref': 'exp/extending_features', 'sha': 'eb51f2ec35acbb873fe17f9508897f7146e07694', 'user': {'login': 'dlt-hub', 'id': 89419010, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg5NDE5MDEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/dlt-hub', 'html_url': 'https://github.com/dlt-hub', 'followers_url': 'https://api.github.com/users/dlt-hub/followers', 'following_url': 'https://api.github.com/users/dlt-hub/following{/other_user}', 'gists_url': 'https://api.github.com/users/dlt-hub/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/dlt-hub/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/dlt-hub/subscriptions', 'organizations_url': 'https://api.github.com/users/dlt-hub/orgs', 'repos_url': 'https://api.github.com/users/dlt-hub/repos', 'events_url': 'https://api.github.com/users/dlt-hub/events{/privacy}', 're ...
# 30 [{'id': '44908815179', 'type': 'MemberEvent', 'actor': {'id': 17202864, 'login': 'rudolfix', 'display_login': 'rudolfix', 'gravatar_id': '', 'url': 'https://api.github.com/users/rudolfix', 'avatar_url': 'https://avatars.githubusercontent.com/u/17202864?'}, 'repo': {'id': 584776311, 'name': 'dlt-hub/verified-sources', 'url': 'https://api.github.com/repos/dlt-hub/verified-sources'}, 'payload': {'member': {'login': 'zilto', 'id': 68975210, 'node_id': 'MDQ6VXNlcjY4OTc1MjEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/68975210?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/zilto', 'html_url': 'https://github.com/zilto', 'followers_url': 'https://api.github.com/users/zilto/followers', 'following_url': 'https://api.github.com/users/zilto/following{/other_user}', 'gists_url': 'https://api.github.com/users/zilto/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/zilto/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/zilto/subscriptions', 'organizations_url': 'https://api.github.com/users/zilto/orgs', 'repos_url': 'https://api.github.com/users/zilto/repos', 'events_url': 'https://api.github.com/users/zilto/events{/privacy}', 'received_events_url': 'https://api.github.com/users/zilto/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'action': 'added'}, 'public': True, 'created_at': '2024-12-18T13:40:52Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '44908367995', 'type': 'IssueCommentEvent', 'actor': {'id': 1155738, 'login': 'sh-rp', 'display_login': 'sh-rp', 'gravatar_id': '', 'url': 'https://api.github.com/users/sh-rp', 'avatar_url': 'https://avatars.githubusercontent.com/u/1155738?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'created', 'issue': {'url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2083', 'repository_url': 'https://api.github.com/repos/dlt-hub/dlt', 'labels_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2083/labels{/name}', 'comments_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2083/comments', 'events_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2083/events', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2083', 'id': 2679200513, 'node_id': 'PR_kwDOGvRYu86Cp_zK', 'number': 2083, 'title': 'chore: devenv environment', 'user': {'login': 'joscha', 'id': 188038, 'node_id': 'MDQ6VXNlcjE4ODAzOA==', 'avatar_url': 'https://avatars.githubusercontent.com/u/188038?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/joscha', 'html_url': 'https://github.com/joscha', 'followers_url': 'https://api.github.com/users/joscha/followers', 'following_url': 'https://api.github.com/users/joscha/following{/other_user}', 'gists_url': 'https://api.github.com/users/joscha/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/joscha/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/joscha/subscriptions', 'organizations_url': 'https://api.github.com/users/joscha/orgs', 'repos_url': 'https://api.github.com/users/joscha/repos', 'events_url': 'https://api.github.com/users/joscha/events{/privacy}', 'received_events_url': 'https://api.github.com/users/joscha/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'labels': [], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 4, 'created_at': '2024-11-21T11:49:13Z', 'updated_at': '2024-12-18T13:28:36Z', 'closed_at': None, 'author_association': 'CONTRIBUTOR', 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2083', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2083', 'diff_url': 'https://github.com/dlt-hub/dlt/pull/2083.diff', 'patch_url': 'https://github.com/dlt-h ...
# 30 [{'id': '44879293618', 'type': 'PushEvent', 'actor': {'id': 17202864, 'login': 'rudolfix', 'display_login': 'rudolfix', 'gravatar_id': '', 'url': 'https://api.github.com/users/rudolfix', 'avatar_url': 'https://avatars.githubusercontent.com/u/17202864?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'repository_id': 452221115, 'push_id': 21755411356, 'size': 24, 'distinct_size': 1, 'ref': 'refs/heads/master', 'head': 'e8c5e9bb0b54f08232c11f7c6455656bc9ee220d', 'before': 'f0690715274590fc4cacf1165e3661aaa7af1c15', 'commits': [{'sha': '54a8cf0075178e53e371cdefd3c0c8fdebcf8ba7', 'author': {'email': 'michalmzawadzki@gmail.com', 'name': 'Michał Zawadzki'}, 'message': 'Docs: add missing mention of the required `endpoint_url` config (#2120)', 'distinct': False, 'url': 'https://api.github.com/repos/dlt-hub/dlt/commits/54a8cf0075178e53e371cdefd3c0c8fdebcf8ba7'}, {'sha': '31fa78c063d39582a43acf89eaa60eb08035d2a6', 'author': {'email': 'anton.burnashev@gmail.com', 'name': 'Anton Burnashev'}, 'message': 'Fix formatting in dlt.common.libs.pyarrow (#2102)', 'distinct': False, 'url': 'https://api.github.com/repos/dlt-hub/dlt/commits/31fa78c063d39582a43acf89eaa60eb08035d2a6'}, {'sha': '6602f70dd63703b9953d43edb9aca1a719a8f7a3', 'author': {'email': 'rudolfix@rudolfix.org', 'name': 'rudolfix'}, 'message': 'checks notebook presence before finding userdata (#2117)', 'distinct': False, 'url': 'https://api.github.com/repos/dlt-hub/dlt/commits/6602f70dd63703b9953d43edb9aca1a719a8f7a3'}, {'sha': '51b11d24acf579d4f12abc15f2b661778f2995d9', 'author': {'email': 'steini90@gmail.com', 'name': 'Steinthor Palsson'}, 'message': "Add open/closed range arguments for incremental (#1991)\n\n* Add open/closed range arguments for incremental\r\n\r\n* Docs for incremental range args\r\n\r\n* Docstring\r\n\r\n* Typo\r\n\r\n* Ensure deduplication is disabled when range_start=='open'\r\n\r\n* Cache transformer settings", 'distinct': False, 'url': 'https://api.github.com/repos/dlt-hub/dlt/commits/51b11d24acf579d4f12abc15f2b661778f2995d9'}, {'sha': '80ef80401b97646901b48e15dade262ef5c3fd52', 'author': {'email': 'shrps@posteo.net', 'name': 'David Scharf'}, 'message': 'bump semver to minimum version 3.0.0 (#2132)', 'distinct': False, 'url': 'https://api.github.com/repos/dlt-hub/dlt/commits/80ef80401b97646901b48e15dade262ef5c3fd52'}, {'sha': '77d8ab6ee23518213fe9da60c4275784450f98fa', 'author': {'email': 'shrps@posteo.net', 'name': 'David Scharf'}, 'message': 'leverage ibis expression for getting readablerelations (#2046)\n\n* add ibis dataset in own class for now\r\n\r\n* make error clearer\r\n\r\n* fix some linting and fix broken test\r\n\r\n* make most destinations work with selecting the right db and catalog, transpiling sql via postgres in some cases and selecting the right dialect in others\r\n\r\n* add missing motherduck and sqlalchemy mappings\r\n\r\n* casefold identifiers for ibis wrapper calss\r\n\r\n* re-organize existing dataset code to prepare ibis relation integration\r\n\r\n* integrate ibis relation into existing code\r\n\r\n* re-order tests\r\n\r\n* fall back to default dataset if table not in schema\r\n\r\n* make dataset type selectable\r\n\r\n* add dataset type selection test and fix bug in tests\r\n\r\n* update docs for ibis expressions use\r\n\r\n* ensure a bunch of ibis operations continue working\r\n\r\n* add some more tests and typings\r\n\r\n* fix typing (with brute force get_attr typing..)\r\n\r\n* move ibis to dependency group\r\n\r\n* move ibis stuff to helpers\r\n\r\n* post devel merge, put in change from dataset, update lockfile\r\n\r\n* add ibis to sqlalchemy tests\r\n\r\n* improve docs a bit\r\n\r\n* fix ibis dep group\r\n\r\n* fix dataset snippets\r\n\r\n* fix ibis version\r\n\r\n* add support for column schema in certion query cases\r\n\r\n---------\r\n\r\nCo-authored-by: Marcin Rudolf <rudolfix@rudolfix.org>', 'distinct': False, 'url': 'https://api.github.com/repos/dlt-hu ...
# 24 [{'id': '44866757132', 'type': 'PullRequestReviewCommentEvent', 'actor': {'id': 9139429, 'login': 'VioletM', 'display_login': 'VioletM', 'gravatar_id': '', 'url': 'https://api.github.com/users/VioletM', 'avatar_url': 'https://avatars.githubusercontent.com/u/9139429?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'created', 'comment': {'url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/comments/1888466018', 'pull_request_review_id': 2508795285, 'id': 1888466018, 'node_id': 'PRRC_kwDOGvRYu85wj7Ri', 'diff_hunk': '@@ -6,33 +6,71 @@ keywords: [architecture, extract, normalize, load]\n \n # How `dlt` works\n \n-`dlt` automatically turns JSON returned by any [source](../../general-usage/glossary.md#source)\n-(e.g., an API) into a live dataset stored in the\n-[destination](../../general-usage/glossary.md#destination) of your choice (e.g., Google BigQuery). It\n-does this by first [extracting](how-dlt-works.md#extract) the JSON data, then\n-[normalizing](how-dlt-works.md#normalize) it to a schema, and finally [loading](how-dlt-works#load)\n-it to the location where you will store it.\n+In a nutshell, `dlt` automatically turns data from a number of available [sources](../../dlt-ecosystem/verified-sources) (e.g., an API, a PostgreSQL database, or Python data structures) into a live dataset stored in a [destination](../../dlt-ecosystem/destinations) of your choice (e.g., Google BigQuery, a Deltalake on Azure, or by pushing the data back via reverse ETL). You can easily implement your own sources, as long as you yield data in a way that is compatible with `dlt`, such as JSON objects, Python lists and dictionaries, pandas dataframes, and arrow tables. `dlt` will be able to automatically compute the schema and move the data to your destination.\n \n-![architecture-diagram](/img/architecture-diagram.png)\n+![architecture-diagram](/img/dlt-onepager.png)\n \n-## Extract\n+## A concrete example\n \n-The Python script requests data from an API or a similar\n-[source](../../general-usage/glossary.md#source). Once this data is received, the script parses the\n-JSON and provides it to `dlt` as input, which then normalizes that data.\n+The main building block of `dlt` is the [pipeline](../../general-usage/glossary.md#pipeline), which orchestrates the loading of data from your source into your destination in three discrete steps when you call its `run` method. Consider this intentionally short example:\n \n-## Normalize\n+```py\n+import dlt\n \n-The configurable normalization engine in `dlt` recursively unpacks this nested structure into\n-relational tables (i.e., inferring data types, linking tables to create nested relationships,\n-etc.), making it ready to be loaded. This creates a\n-[schema](../../general-usage/glossary.md#schema), which will automatically evolve to accommodate any future\n-source data changes (e.g., new fields or tables).\n+pipeline = dlt.pipeline(pipeline_name="my_pipeline", destination="duckdb")\n+pipeline.run(\n+    [\n+        {"id": 1},\n+        {"id": 2},\n+        {"id": 3, "nested": [{"id": 1}, {"id": 2}]},\n+    ],\n+    table_name="items",\n+)\n+```\n \n-## Load\n+This is what happens when the `run` method is executed:\n \n-The data is then loaded into your chosen [destination](../../general-usage/glossary.md#destination).\n-`dlt` uses configurable, idempotent, atomic loads that ensure data safely ends up there. For\n-example, you don\'t need to worry about the size of the data you are loading, and if the process is\n-interrupted, it is safe to retry without creating errors.\n+1. [Extract](how-dlt-works.md#extract) - Fully extracts the data from your source to your hard drive. In the example above, an implicit source with one resource with 3 items is created and extracted.\n+2. [Normalize](how-dlt-works.md#normalize) - Inspects and normalizes your data and computes a schema compatible with your destination. For the example above, the  ...

# %% [markdown]
# Pagination type was detected automatically, but you can explicitly provide it:

# %%
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.paginators import HeaderLinkPaginator

client = RESTClient(
    base_url="https://api.github.com",
    paginator=HeaderLinkPaginator(),
)

# %% [markdown]
# The full list of available paginators you can see in offcial [dlt documentation](https://dlthub.com/docs/general-usage/http/rest-client#paginators).

# %% [markdown]
# ![Screenshot 2024-12-13 at 16.09.04.png](data:image/png;base64,...)

# %% [markdown]
# Endpoint events has not so much data as for example enpoint stargazers for dlt repo. If you run the pipeline for endpoint stargazers, there is a high chance that you face the **rate limit error**.

# %%
from dlt.sources.helpers.rest_client import RESTClient


client = RESTClient(
    base_url="https://api.github.com",
)

for page in client.paginate("repos/dlt-hub/dlt/stargazers"):
    print(page)
# Out:
# [{'login': 'lalitpagaria', 'id': 19303690, 'node_id': 'MDQ6VXNlcjE5MzAzNjkw', 'avatar_url': 'https://avatars.githubusercontent.com/u/19303690?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/lalitpagaria', 'html_url': 'https://github.com/lalitpagaria', 'followers_url': 'https://api.github.com/users/lalitpagaria/followers', 'following_url': 'https://api.github.com/users/lalitpagaria/following{/other_user}', 'gists_url': 'https://api.github.com/users/lalitpagaria/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/lalitpagaria/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/lalitpagaria/subscriptions', 'organizations_url': 'https://api.github.com/users/lalitpagaria/orgs', 'repos_url': 'https://api.github.com/users/lalitpagaria/repos', 'events_url': 'https://api.github.com/users/lalitpagaria/events{/privacy}', 'received_events_url': 'https://api.github.com/users/lalitpagaria/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'nikitavoloboev', 'id': 6391776, 'node_id': 'MDQ6VXNlcjYzOTE3NzY=', 'avatar_url': 'https://avatars.githubusercontent.com/u/6391776?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/nikitavoloboev', 'html_url': 'https://github.com/nikitavoloboev', 'followers_url': 'https://api.github.com/users/nikitavoloboev/followers', 'following_url': 'https://api.github.com/users/nikitavoloboev/following{/other_user}', 'gists_url': 'https://api.github.com/users/nikitavoloboev/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/nikitavoloboev/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/nikitavoloboev/subscriptions', 'organizations_url': 'https://api.github.com/users/nikitavoloboev/orgs', 'repos_url': 'https://api.github.com/users/nikitavoloboev/repos', 'events_url': 'https://api.github.com/users/nikitavoloboev/events{/privacy}', 'received_events_url': 'https://api.github.com/users/nikitavoloboev/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'gerrykou', 'id': 13572514, 'node_id': 'MDQ6VXNlcjEzNTcyNTE0', 'avatar_url': 'https://avatars.githubusercontent.com/u/13572514?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/gerrykou', 'html_url': 'https://github.com/gerrykou', 'followers_url': 'https://api.github.com/users/gerrykou/followers', 'following_url': 'https://api.github.com/users/gerrykou/following{/other_user}', 'gists_url': 'https://api.github.com/users/gerrykou/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/gerrykou/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/gerrykou/subscriptions', 'organizations_url': 'https://api.github.com/users/gerrykou/orgs', 'repos_url': 'https://api.github.com/users/gerrykou/repos', 'events_url': 'https://api.github.com/users/gerrykou/events{/privacy}', 'received_events_url': 'https://api.github.com/users/gerrykou/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'jdmonty', 'id': 3614077, 'node_id': 'MDQ6VXNlcjM2MTQwNzc=', 'avatar_url': 'https://avatars.githubusercontent.com/u/3614077?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jdmonty', 'html_url': 'https://github.com/jdmonty', 'followers_url': 'https://api.github.com/users/jdmonty/followers', 'following_url': 'https://api.github.com/users/jdmonty/following{/other_user}', 'gists_url': 'https://api.github.com/users/jdmonty/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jdmonty/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jdmonty/subscriptions', 'organizations_url': 'https://api.github.com/users/jdmonty/orgs', 'repos_url': 'https://api.github.com/users/jdmonty/repos', 'events_url': 'https://api.github.com/users/jdmonty/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jdmonty/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login ...
# [{'login': 'jankatins', 'id': 890156, 'node_id': 'MDQ6VXNlcjg5MDE1Ng==', 'avatar_url': 'https://avatars.githubusercontent.com/u/890156?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jankatins', 'html_url': 'https://github.com/jankatins', 'followers_url': 'https://api.github.com/users/jankatins/followers', 'following_url': 'https://api.github.com/users/jankatins/following{/other_user}', 'gists_url': 'https://api.github.com/users/jankatins/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jankatins/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jankatins/subscriptions', 'organizations_url': 'https://api.github.com/users/jankatins/orgs', 'repos_url': 'https://api.github.com/users/jankatins/repos', 'events_url': 'https://api.github.com/users/jankatins/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jankatins/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'Tafkas', 'id': 34058, 'node_id': 'MDQ6VXNlcjM0MDU4', 'avatar_url': 'https://avatars.githubusercontent.com/u/34058?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Tafkas', 'html_url': 'https://github.com/Tafkas', 'followers_url': 'https://api.github.com/users/Tafkas/followers', 'following_url': 'https://api.github.com/users/Tafkas/following{/other_user}', 'gists_url': 'https://api.github.com/users/Tafkas/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Tafkas/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Tafkas/subscriptions', 'organizations_url': 'https://api.github.com/users/Tafkas/orgs', 'repos_url': 'https://api.github.com/users/Tafkas/repos', 'events_url': 'https://api.github.com/users/Tafkas/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Tafkas/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'chris-park', 'id': 58880657, 'node_id': 'MDQ6VXNlcjU4ODgwNjU3', 'avatar_url': 'https://avatars.githubusercontent.com/u/58880657?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/chris-park', 'html_url': 'https://github.com/chris-park', 'followers_url': 'https://api.github.com/users/chris-park/followers', 'following_url': 'https://api.github.com/users/chris-park/following{/other_user}', 'gists_url': 'https://api.github.com/users/chris-park/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/chris-park/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/chris-park/subscriptions', 'organizations_url': 'https://api.github.com/users/chris-park/orgs', 'repos_url': 'https://api.github.com/users/chris-park/repos', 'events_url': 'https://api.github.com/users/chris-park/events{/privacy}', 'received_events_url': 'https://api.github.com/users/chris-park/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'ddeveloperr', 'id': 10800686, 'node_id': 'MDQ6VXNlcjEwODAwNjg2', 'avatar_url': 'https://avatars.githubusercontent.com/u/10800686?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ddeveloperr', 'html_url': 'https://github.com/ddeveloperr', 'followers_url': 'https://api.github.com/users/ddeveloperr/followers', 'following_url': 'https://api.github.com/users/ddeveloperr/following{/other_user}', 'gists_url': 'https://api.github.com/users/ddeveloperr/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ddeveloperr/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ddeveloperr/subscriptions', 'organizations_url': 'https://api.github.com/users/ddeveloperr/orgs', 'repos_url': 'https://api.github.com/users/ddeveloperr/repos', 'events_url': 'https://api.github.com/users/ddeveloperr/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ddeveloperr/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'jpmmcneill', 'id': 55981540, 'node_id': 'MDQ6VXNlcjU1OTgxNTQw', 'a ...
# [{'login': 'z3z1ma', 'id': 41213451, 'node_id': 'MDQ6VXNlcjQxMjEzNDUx', 'avatar_url': 'https://avatars.githubusercontent.com/u/41213451?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/z3z1ma', 'html_url': 'https://github.com/z3z1ma', 'followers_url': 'https://api.github.com/users/z3z1ma/followers', 'following_url': 'https://api.github.com/users/z3z1ma/following{/other_user}', 'gists_url': 'https://api.github.com/users/z3z1ma/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/z3z1ma/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/z3z1ma/subscriptions', 'organizations_url': 'https://api.github.com/users/z3z1ma/orgs', 'repos_url': 'https://api.github.com/users/z3z1ma/repos', 'events_url': 'https://api.github.com/users/z3z1ma/events{/privacy}', 'received_events_url': 'https://api.github.com/users/z3z1ma/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'shimonymittal', 'id': 95504257, 'node_id': 'U_kgDOBbFHgQ', 'avatar_url': 'https://avatars.githubusercontent.com/u/95504257?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/shimonymittal', 'html_url': 'https://github.com/shimonymittal', 'followers_url': 'https://api.github.com/users/shimonymittal/followers', 'following_url': 'https://api.github.com/users/shimonymittal/following{/other_user}', 'gists_url': 'https://api.github.com/users/shimonymittal/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/shimonymittal/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/shimonymittal/subscriptions', 'organizations_url': 'https://api.github.com/users/shimonymittal/orgs', 'repos_url': 'https://api.github.com/users/shimonymittal/repos', 'events_url': 'https://api.github.com/users/shimonymittal/events{/privacy}', 'received_events_url': 'https://api.github.com/users/shimonymittal/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'livioso', 'id': 1672198, 'node_id': 'MDQ6VXNlcjE2NzIxOTg=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1672198?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/livioso', 'html_url': 'https://github.com/livioso', 'followers_url': 'https://api.github.com/users/livioso/followers', 'following_url': 'https://api.github.com/users/livioso/following{/other_user}', 'gists_url': 'https://api.github.com/users/livioso/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/livioso/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/livioso/subscriptions', 'organizations_url': 'https://api.github.com/users/livioso/orgs', 'repos_url': 'https://api.github.com/users/livioso/repos', 'events_url': 'https://api.github.com/users/livioso/events{/privacy}', 'received_events_url': 'https://api.github.com/users/livioso/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'tungbq', 'id': 85242618, 'node_id': 'MDQ6VXNlcjg1MjQyNjE4', 'avatar_url': 'https://avatars.githubusercontent.com/u/85242618?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/tungbq', 'html_url': 'https://github.com/tungbq', 'followers_url': 'https://api.github.com/users/tungbq/followers', 'following_url': 'https://api.github.com/users/tungbq/following{/other_user}', 'gists_url': 'https://api.github.com/users/tungbq/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/tungbq/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/tungbq/subscriptions', 'organizations_url': 'https://api.github.com/users/tungbq/orgs', 'repos_url': 'https://api.github.com/users/tungbq/repos', 'events_url': 'https://api.github.com/users/tungbq/events{/privacy}', 'received_events_url': 'https://api.github.com/users/tungbq/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'VincenzoGalante', 'id': 79586031, 'node_id': 'MDQ6VXNlcjc5NTg2MDMx', 'avatar_url': 'https://avatars.githubuser ...
# [{'login': 'yliapis', 'id': 14884413, 'node_id': 'MDQ6VXNlcjE0ODg0NDEz', 'avatar_url': 'https://avatars.githubusercontent.com/u/14884413?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/yliapis', 'html_url': 'https://github.com/yliapis', 'followers_url': 'https://api.github.com/users/yliapis/followers', 'following_url': 'https://api.github.com/users/yliapis/following{/other_user}', 'gists_url': 'https://api.github.com/users/yliapis/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/yliapis/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/yliapis/subscriptions', 'organizations_url': 'https://api.github.com/users/yliapis/orgs', 'repos_url': 'https://api.github.com/users/yliapis/repos', 'events_url': 'https://api.github.com/users/yliapis/events{/privacy}', 'received_events_url': 'https://api.github.com/users/yliapis/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'thisisdope', 'id': 32782533, 'node_id': 'MDQ6VXNlcjMyNzgyNTMz', 'avatar_url': 'https://avatars.githubusercontent.com/u/32782533?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/thisisdope', 'html_url': 'https://github.com/thisisdope', 'followers_url': 'https://api.github.com/users/thisisdope/followers', 'following_url': 'https://api.github.com/users/thisisdope/following{/other_user}', 'gists_url': 'https://api.github.com/users/thisisdope/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/thisisdope/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/thisisdope/subscriptions', 'organizations_url': 'https://api.github.com/users/thisisdope/orgs', 'repos_url': 'https://api.github.com/users/thisisdope/repos', 'events_url': 'https://api.github.com/users/thisisdope/events{/privacy}', 'received_events_url': 'https://api.github.com/users/thisisdope/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'tconbeer', 'id': 705906, 'node_id': 'MDQ6VXNlcjcwNTkwNg==', 'avatar_url': 'https://avatars.githubusercontent.com/u/705906?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/tconbeer', 'html_url': 'https://github.com/tconbeer', 'followers_url': 'https://api.github.com/users/tconbeer/followers', 'following_url': 'https://api.github.com/users/tconbeer/following{/other_user}', 'gists_url': 'https://api.github.com/users/tconbeer/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/tconbeer/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/tconbeer/subscriptions', 'organizations_url': 'https://api.github.com/users/tconbeer/orgs', 'repos_url': 'https://api.github.com/users/tconbeer/repos', 'events_url': 'https://api.github.com/users/tconbeer/events{/privacy}', 'received_events_url': 'https://api.github.com/users/tconbeer/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'davidharting', 'id': 6146772, 'node_id': 'MDQ6VXNlcjYxNDY3NzI=', 'avatar_url': 'https://avatars.githubusercontent.com/u/6146772?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/davidharting', 'html_url': 'https://github.com/davidharting', 'followers_url': 'https://api.github.com/users/davidharting/followers', 'following_url': 'https://api.github.com/users/davidharting/following{/other_user}', 'gists_url': 'https://api.github.com/users/davidharting/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/davidharting/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/davidharting/subscriptions', 'organizations_url': 'https://api.github.com/users/davidharting/orgs', 'repos_url': 'https://api.github.com/users/davidharting/repos', 'events_url': 'https://api.github.com/users/davidharting/events{/privacy}', 'received_events_url': 'https://api.github.com/users/davidharting/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'kwigley', 'id': 9877221, 'node_id': 'MDQ6VXNlc ...
# [{'login': 'mrnitrate', 'id': 1325392, 'node_id': 'MDQ6VXNlcjEzMjUzOTI=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1325392?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/mrnitrate', 'html_url': 'https://github.com/mrnitrate', 'followers_url': 'https://api.github.com/users/mrnitrate/followers', 'following_url': 'https://api.github.com/users/mrnitrate/following{/other_user}', 'gists_url': 'https://api.github.com/users/mrnitrate/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/mrnitrate/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/mrnitrate/subscriptions', 'organizations_url': 'https://api.github.com/users/mrnitrate/orgs', 'repos_url': 'https://api.github.com/users/mrnitrate/repos', 'events_url': 'https://api.github.com/users/mrnitrate/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mrnitrate/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'unarmedcivilian', 'id': 8530446, 'node_id': 'MDQ6VXNlcjg1MzA0NDY=', 'avatar_url': 'https://avatars.githubusercontent.com/u/8530446?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/unarmedcivilian', 'html_url': 'https://github.com/unarmedcivilian', 'followers_url': 'https://api.github.com/users/unarmedcivilian/followers', 'following_url': 'https://api.github.com/users/unarmedcivilian/following{/other_user}', 'gists_url': 'https://api.github.com/users/unarmedcivilian/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/unarmedcivilian/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/unarmedcivilian/subscriptions', 'organizations_url': 'https://api.github.com/users/unarmedcivilian/orgs', 'repos_url': 'https://api.github.com/users/unarmedcivilian/repos', 'events_url': 'https://api.github.com/users/unarmedcivilian/events{/privacy}', 'received_events_url': 'https://api.github.com/users/unarmedcivilian/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'abhilashchowdhary', 'id': 18218120, 'node_id': 'MDQ6VXNlcjE4MjE4MTIw', 'avatar_url': 'https://avatars.githubusercontent.com/u/18218120?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/abhilashchowdhary', 'html_url': 'https://github.com/abhilashchowdhary', 'followers_url': 'https://api.github.com/users/abhilashchowdhary/followers', 'following_url': 'https://api.github.com/users/abhilashchowdhary/following{/other_user}', 'gists_url': 'https://api.github.com/users/abhilashchowdhary/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/abhilashchowdhary/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/abhilashchowdhary/subscriptions', 'organizations_url': 'https://api.github.com/users/abhilashchowdhary/orgs', 'repos_url': 'https://api.github.com/users/abhilashchowdhary/repos', 'events_url': 'https://api.github.com/users/abhilashchowdhary/events{/privacy}', 'received_events_url': 'https://api.github.com/users/abhilashchowdhary/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'jckail', 'id': 13952435, 'node_id': 'MDQ6VXNlcjEzOTUyNDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/13952435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jckail', 'html_url': 'https://github.com/jckail', 'followers_url': 'https://api.github.com/users/jckail/followers', 'following_url': 'https://api.github.com/users/jckail/following{/other_user}', 'gists_url': 'https://api.github.com/users/jckail/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jckail/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jckail/subscriptions', 'organizations_url': 'https://api.github.com/users/jckail/orgs', 'repos_url': 'https://api.github.com/users/jckail/repos', 'events_url': 'https://api.github.com/users/jckail/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jckail/received_events', ' ...
# [{'login': 'adrivn', 'id': 42723006, 'node_id': 'MDQ6VXNlcjQyNzIzMDA2', 'avatar_url': 'https://avatars.githubusercontent.com/u/42723006?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/adrivn', 'html_url': 'https://github.com/adrivn', 'followers_url': 'https://api.github.com/users/adrivn/followers', 'following_url': 'https://api.github.com/users/adrivn/following{/other_user}', 'gists_url': 'https://api.github.com/users/adrivn/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/adrivn/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/adrivn/subscriptions', 'organizations_url': 'https://api.github.com/users/adrivn/orgs', 'repos_url': 'https://api.github.com/users/adrivn/repos', 'events_url': 'https://api.github.com/users/adrivn/events{/privacy}', 'received_events_url': 'https://api.github.com/users/adrivn/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'Conq1', 'id': 19863623, 'node_id': 'MDQ6VXNlcjE5ODYzNjIz', 'avatar_url': 'https://avatars.githubusercontent.com/u/19863623?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Conq1', 'html_url': 'https://github.com/Conq1', 'followers_url': 'https://api.github.com/users/Conq1/followers', 'following_url': 'https://api.github.com/users/Conq1/following{/other_user}', 'gists_url': 'https://api.github.com/users/Conq1/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Conq1/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Conq1/subscriptions', 'organizations_url': 'https://api.github.com/users/Conq1/orgs', 'repos_url': 'https://api.github.com/users/Conq1/repos', 'events_url': 'https://api.github.com/users/Conq1/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Conq1/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'tiagotcunha', 'id': 10522134, 'node_id': 'MDQ6VXNlcjEwNTIyMTM0', 'avatar_url': 'https://avatars.githubusercontent.com/u/10522134?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/tiagotcunha', 'html_url': 'https://github.com/tiagotcunha', 'followers_url': 'https://api.github.com/users/tiagotcunha/followers', 'following_url': 'https://api.github.com/users/tiagotcunha/following{/other_user}', 'gists_url': 'https://api.github.com/users/tiagotcunha/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/tiagotcunha/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/tiagotcunha/subscriptions', 'organizations_url': 'https://api.github.com/users/tiagotcunha/orgs', 'repos_url': 'https://api.github.com/users/tiagotcunha/repos', 'events_url': 'https://api.github.com/users/tiagotcunha/events{/privacy}', 'received_events_url': 'https://api.github.com/users/tiagotcunha/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'dvd3v', 'id': 16576928, 'node_id': 'MDQ6VXNlcjE2NTc2OTI4', 'avatar_url': 'https://avatars.githubusercontent.com/u/16576928?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/dvd3v', 'html_url': 'https://github.com/dvd3v', 'followers_url': 'https://api.github.com/users/dvd3v/followers', 'following_url': 'https://api.github.com/users/dvd3v/following{/other_user}', 'gists_url': 'https://api.github.com/users/dvd3v/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/dvd3v/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/dvd3v/subscriptions', 'organizations_url': 'https://api.github.com/users/dvd3v/orgs', 'repos_url': 'https://api.github.com/users/dvd3v/repos', 'events_url': 'https://api.github.com/users/dvd3v/events{/privacy}', 'received_events_url': 'https://api.github.com/users/dvd3v/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'macraesdirtysocks', 'id': 78040749, 'node_id': 'MDQ6VXNlcjc4MDQwNzQ5', 'avatar_url': 'https://avatars.githubusercontent.com/u/78040749?v=4', 'gravatar_id': '',  ...
# [{'login': 'pbadeer', 'id': 467756, 'node_id': 'MDQ6VXNlcjQ2Nzc1Ng==', 'avatar_url': 'https://avatars.githubusercontent.com/u/467756?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/pbadeer', 'html_url': 'https://github.com/pbadeer', 'followers_url': 'https://api.github.com/users/pbadeer/followers', 'following_url': 'https://api.github.com/users/pbadeer/following{/other_user}', 'gists_url': 'https://api.github.com/users/pbadeer/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/pbadeer/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/pbadeer/subscriptions', 'organizations_url': 'https://api.github.com/users/pbadeer/orgs', 'repos_url': 'https://api.github.com/users/pbadeer/repos', 'events_url': 'https://api.github.com/users/pbadeer/events{/privacy}', 'received_events_url': 'https://api.github.com/users/pbadeer/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'cuddebtj', 'id': 65567376, 'node_id': 'MDQ6VXNlcjY1NTY3Mzc2', 'avatar_url': 'https://avatars.githubusercontent.com/u/65567376?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/cuddebtj', 'html_url': 'https://github.com/cuddebtj', 'followers_url': 'https://api.github.com/users/cuddebtj/followers', 'following_url': 'https://api.github.com/users/cuddebtj/following{/other_user}', 'gists_url': 'https://api.github.com/users/cuddebtj/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/cuddebtj/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/cuddebtj/subscriptions', 'organizations_url': 'https://api.github.com/users/cuddebtj/orgs', 'repos_url': 'https://api.github.com/users/cuddebtj/repos', 'events_url': 'https://api.github.com/users/cuddebtj/events{/privacy}', 'received_events_url': 'https://api.github.com/users/cuddebtj/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'let-me-cook', 'id': 35270908, 'node_id': 'MDQ6VXNlcjM1MjcwOTA4', 'avatar_url': 'https://avatars.githubusercontent.com/u/35270908?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/let-me-cook', 'html_url': 'https://github.com/let-me-cook', 'followers_url': 'https://api.github.com/users/let-me-cook/followers', 'following_url': 'https://api.github.com/users/let-me-cook/following{/other_user}', 'gists_url': 'https://api.github.com/users/let-me-cook/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/let-me-cook/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/let-me-cook/subscriptions', 'organizations_url': 'https://api.github.com/users/let-me-cook/orgs', 'repos_url': 'https://api.github.com/users/let-me-cook/repos', 'events_url': 'https://api.github.com/users/let-me-cook/events{/privacy}', 'received_events_url': 'https://api.github.com/users/let-me-cook/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'il-dat', 'id': 103571964, 'node_id': 'U_kgDOBixh_A', 'avatar_url': 'https://avatars.githubusercontent.com/u/103571964?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/il-dat', 'html_url': 'https://github.com/il-dat', 'followers_url': 'https://api.github.com/users/il-dat/followers', 'following_url': 'https://api.github.com/users/il-dat/following{/other_user}', 'gists_url': 'https://api.github.com/users/il-dat/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/il-dat/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/il-dat/subscriptions', 'organizations_url': 'https://api.github.com/users/il-dat/orgs', 'repos_url': 'https://api.github.com/users/il-dat/repos', 'events_url': 'https://api.github.com/users/il-dat/events{/privacy}', 'received_events_url': 'https://api.github.com/users/il-dat/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'rogegoncalves', 'id': 33241020, 'node_id': 'MDQ6VXNlcjMzMjQxMDIw', 'avatar_url': 'https://avatars.githubuserco ...
# [{'login': 'mesmacosta', 'id': 3176836, 'node_id': 'MDQ6VXNlcjMxNzY4MzY=', 'avatar_url': 'https://avatars.githubusercontent.com/u/3176836?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/mesmacosta', 'html_url': 'https://github.com/mesmacosta', 'followers_url': 'https://api.github.com/users/mesmacosta/followers', 'following_url': 'https://api.github.com/users/mesmacosta/following{/other_user}', 'gists_url': 'https://api.github.com/users/mesmacosta/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/mesmacosta/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/mesmacosta/subscriptions', 'organizations_url': 'https://api.github.com/users/mesmacosta/orgs', 'repos_url': 'https://api.github.com/users/mesmacosta/repos', 'events_url': 'https://api.github.com/users/mesmacosta/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mesmacosta/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'samg861', 'id': 16475396, 'node_id': 'MDQ6VXNlcjE2NDc1Mzk2', 'avatar_url': 'https://avatars.githubusercontent.com/u/16475396?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/samg861', 'html_url': 'https://github.com/samg861', 'followers_url': 'https://api.github.com/users/samg861/followers', 'following_url': 'https://api.github.com/users/samg861/following{/other_user}', 'gists_url': 'https://api.github.com/users/samg861/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/samg861/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/samg861/subscriptions', 'organizations_url': 'https://api.github.com/users/samg861/orgs', 'repos_url': 'https://api.github.com/users/samg861/repos', 'events_url': 'https://api.github.com/users/samg861/events{/privacy}', 'received_events_url': 'https://api.github.com/users/samg861/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'itroulli', 'id': 15125321, 'node_id': 'MDQ6VXNlcjE1MTI1MzIx', 'avatar_url': 'https://avatars.githubusercontent.com/u/15125321?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/itroulli', 'html_url': 'https://github.com/itroulli', 'followers_url': 'https://api.github.com/users/itroulli/followers', 'following_url': 'https://api.github.com/users/itroulli/following{/other_user}', 'gists_url': 'https://api.github.com/users/itroulli/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/itroulli/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/itroulli/subscriptions', 'organizations_url': 'https://api.github.com/users/itroulli/orgs', 'repos_url': 'https://api.github.com/users/itroulli/repos', 'events_url': 'https://api.github.com/users/itroulli/events{/privacy}', 'received_events_url': 'https://api.github.com/users/itroulli/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'match-gabeflores', 'id': 286903, 'node_id': 'MDQ6VXNlcjI4NjkwMw==', 'avatar_url': 'https://avatars.githubusercontent.com/u/286903?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/match-gabeflores', 'html_url': 'https://github.com/match-gabeflores', 'followers_url': 'https://api.github.com/users/match-gabeflores/followers', 'following_url': 'https://api.github.com/users/match-gabeflores/following{/other_user}', 'gists_url': 'https://api.github.com/users/match-gabeflores/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/match-gabeflores/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/match-gabeflores/subscriptions', 'organizations_url': 'https://api.github.com/users/match-gabeflores/orgs', 'repos_url': 'https://api.github.com/users/match-gabeflores/repos', 'events_url': 'https://api.github.com/users/match-gabeflores/events{/privacy}', 'received_events_url': 'https://api.github.com/users/match-gabeflores/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': ...
# [{'login': 'lioneltayyd', 'id': 36695608, 'node_id': 'MDQ6VXNlcjM2Njk1NjA4', 'avatar_url': 'https://avatars.githubusercontent.com/u/36695608?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/lioneltayyd', 'html_url': 'https://github.com/lioneltayyd', 'followers_url': 'https://api.github.com/users/lioneltayyd/followers', 'following_url': 'https://api.github.com/users/lioneltayyd/following{/other_user}', 'gists_url': 'https://api.github.com/users/lioneltayyd/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/lioneltayyd/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/lioneltayyd/subscriptions', 'organizations_url': 'https://api.github.com/users/lioneltayyd/orgs', 'repos_url': 'https://api.github.com/users/lioneltayyd/repos', 'events_url': 'https://api.github.com/users/lioneltayyd/events{/privacy}', 'received_events_url': 'https://api.github.com/users/lioneltayyd/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'usr-av', 'id': 14003879, 'node_id': 'MDQ6VXNlcjE0MDAzODc5', 'avatar_url': 'https://avatars.githubusercontent.com/u/14003879?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/usr-av', 'html_url': 'https://github.com/usr-av', 'followers_url': 'https://api.github.com/users/usr-av/followers', 'following_url': 'https://api.github.com/users/usr-av/following{/other_user}', 'gists_url': 'https://api.github.com/users/usr-av/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/usr-av/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/usr-av/subscriptions', 'organizations_url': 'https://api.github.com/users/usr-av/orgs', 'repos_url': 'https://api.github.com/users/usr-av/repos', 'events_url': 'https://api.github.com/users/usr-av/events{/privacy}', 'received_events_url': 'https://api.github.com/users/usr-av/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'datarise', 'id': 57174695, 'node_id': 'MDQ6VXNlcjU3MTc0Njk1', 'avatar_url': 'https://avatars.githubusercontent.com/u/57174695?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/datarise', 'html_url': 'https://github.com/datarise', 'followers_url': 'https://api.github.com/users/datarise/followers', 'following_url': 'https://api.github.com/users/datarise/following{/other_user}', 'gists_url': 'https://api.github.com/users/datarise/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/datarise/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/datarise/subscriptions', 'organizations_url': 'https://api.github.com/users/datarise/orgs', 'repos_url': 'https://api.github.com/users/datarise/repos', 'events_url': 'https://api.github.com/users/datarise/events{/privacy}', 'received_events_url': 'https://api.github.com/users/datarise/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'ancestor-mithril', 'id': 58839912, 'node_id': 'MDQ6VXNlcjU4ODM5OTEy', 'avatar_url': 'https://avatars.githubusercontent.com/u/58839912?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ancestor-mithril', 'html_url': 'https://github.com/ancestor-mithril', 'followers_url': 'https://api.github.com/users/ancestor-mithril/followers', 'following_url': 'https://api.github.com/users/ancestor-mithril/following{/other_user}', 'gists_url': 'https://api.github.com/users/ancestor-mithril/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ancestor-mithril/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ancestor-mithril/subscriptions', 'organizations_url': 'https://api.github.com/users/ancestor-mithril/orgs', 'repos_url': 'https://api.github.com/users/ancestor-mithril/repos', 'events_url': 'https://api.github.com/users/ancestor-mithril/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ancestor-mithril/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'l ...
# [{'login': '16bzwiener', 'id': 18385834, 'node_id': 'MDQ6VXNlcjE4Mzg1ODM0', 'avatar_url': 'https://avatars.githubusercontent.com/u/18385834?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/16bzwiener', 'html_url': 'https://github.com/16bzwiener', 'followers_url': 'https://api.github.com/users/16bzwiener/followers', 'following_url': 'https://api.github.com/users/16bzwiener/following{/other_user}', 'gists_url': 'https://api.github.com/users/16bzwiener/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/16bzwiener/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/16bzwiener/subscriptions', 'organizations_url': 'https://api.github.com/users/16bzwiener/orgs', 'repos_url': 'https://api.github.com/users/16bzwiener/repos', 'events_url': 'https://api.github.com/users/16bzwiener/events{/privacy}', 'received_events_url': 'https://api.github.com/users/16bzwiener/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'mid', 'id': 3770, 'node_id': 'MDQ6VXNlcjM3NzA=', 'avatar_url': 'https://avatars.githubusercontent.com/u/3770?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/mid', 'html_url': 'https://github.com/mid', 'followers_url': 'https://api.github.com/users/mid/followers', 'following_url': 'https://api.github.com/users/mid/following{/other_user}', 'gists_url': 'https://api.github.com/users/mid/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/mid/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/mid/subscriptions', 'organizations_url': 'https://api.github.com/users/mid/orgs', 'repos_url': 'https://api.github.com/users/mid/repos', 'events_url': 'https://api.github.com/users/mid/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mid/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'jazzwang', 'id': 76903, 'node_id': 'MDQ6VXNlcjc2OTAz', 'avatar_url': 'https://avatars.githubusercontent.com/u/76903?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jazzwang', 'html_url': 'https://github.com/jazzwang', 'followers_url': 'https://api.github.com/users/jazzwang/followers', 'following_url': 'https://api.github.com/users/jazzwang/following{/other_user}', 'gists_url': 'https://api.github.com/users/jazzwang/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jazzwang/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jazzwang/subscriptions', 'organizations_url': 'https://api.github.com/users/jazzwang/orgs', 'repos_url': 'https://api.github.com/users/jazzwang/repos', 'events_url': 'https://api.github.com/users/jazzwang/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jazzwang/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'damireh', 'id': 429845, 'node_id': 'MDQ6VXNlcjQyOTg0NQ==', 'avatar_url': 'https://avatars.githubusercontent.com/u/429845?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/damireh', 'html_url': 'https://github.com/damireh', 'followers_url': 'https://api.github.com/users/damireh/followers', 'following_url': 'https://api.github.com/users/damireh/following{/other_user}', 'gists_url': 'https://api.github.com/users/damireh/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/damireh/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/damireh/subscriptions', 'organizations_url': 'https://api.github.com/users/damireh/orgs', 'repos_url': 'https://api.github.com/users/damireh/repos', 'events_url': 'https://api.github.com/users/damireh/events{/privacy}', 'received_events_url': 'https://api.github.com/users/damireh/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'cfahlgren1', 'id': 13546028, 'node_id': 'MDQ6VXNlcjEzNTQ2MDI4', 'avatar_url': 'https://avatars.githubusercontent.com/u/13546028?v=4', 'gravatar_id': '', 'url': 'https://api.g ...
# [{'login': 'cofin', 'id': 204685, 'node_id': 'MDQ6VXNlcjIwNDY4NQ==', 'avatar_url': 'https://avatars.githubusercontent.com/u/204685?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/cofin', 'html_url': 'https://github.com/cofin', 'followers_url': 'https://api.github.com/users/cofin/followers', 'following_url': 'https://api.github.com/users/cofin/following{/other_user}', 'gists_url': 'https://api.github.com/users/cofin/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/cofin/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/cofin/subscriptions', 'organizations_url': 'https://api.github.com/users/cofin/orgs', 'repos_url': 'https://api.github.com/users/cofin/repos', 'events_url': 'https://api.github.com/users/cofin/events{/privacy}', 'received_events_url': 'https://api.github.com/users/cofin/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'Albayrakengin', 'id': 88938152, 'node_id': 'MDQ6VXNlcjg4OTM4MTUy', 'avatar_url': 'https://avatars.githubusercontent.com/u/88938152?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Albayrakengin', 'html_url': 'https://github.com/Albayrakengin', 'followers_url': 'https://api.github.com/users/Albayrakengin/followers', 'following_url': 'https://api.github.com/users/Albayrakengin/following{/other_user}', 'gists_url': 'https://api.github.com/users/Albayrakengin/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Albayrakengin/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Albayrakengin/subscriptions', 'organizations_url': 'https://api.github.com/users/Albayrakengin/orgs', 'repos_url': 'https://api.github.com/users/Albayrakengin/repos', 'events_url': 'https://api.github.com/users/Albayrakengin/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Albayrakengin/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'aerofeev', 'id': 6343458, 'node_id': 'MDQ6VXNlcjYzNDM0NTg=', 'avatar_url': 'https://avatars.githubusercontent.com/u/6343458?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/aerofeev', 'html_url': 'https://github.com/aerofeev', 'followers_url': 'https://api.github.com/users/aerofeev/followers', 'following_url': 'https://api.github.com/users/aerofeev/following{/other_user}', 'gists_url': 'https://api.github.com/users/aerofeev/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/aerofeev/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/aerofeev/subscriptions', 'organizations_url': 'https://api.github.com/users/aerofeev/orgs', 'repos_url': 'https://api.github.com/users/aerofeev/repos', 'events_url': 'https://api.github.com/users/aerofeev/events{/privacy}', 'received_events_url': 'https://api.github.com/users/aerofeev/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'bayees', 'id': 1546610, 'node_id': 'MDQ6VXNlcjE1NDY2MTA=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1546610?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/bayees', 'html_url': 'https://github.com/bayees', 'followers_url': 'https://api.github.com/users/bayees/followers', 'following_url': 'https://api.github.com/users/bayees/following{/other_user}', 'gists_url': 'https://api.github.com/users/bayees/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/bayees/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/bayees/subscriptions', 'organizations_url': 'https://api.github.com/users/bayees/orgs', 'repos_url': 'https://api.github.com/users/bayees/repos', 'events_url': 'https://api.github.com/users/bayees/events{/privacy}', 'received_events_url': 'https://api.github.com/users/bayees/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'asavitski', 'id': 4550995, 'node_id': 'MDQ6VXNlcjQ1NTA5OTU=', 'avatar_url': 'https://avatars.githubuserconte ...
# ...
# [{'login': 'askmetoo', 'id': 51628970, 'node_id': 'MDQ6VXNlcjUxNjI4OTcw', 'avatar_url': 'https://avatars.githubusercontent.com/u/51628970?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/askmetoo', 'html_url': 'https://github.com/askmetoo', 'followers_url': 'https://api.github.com/users/askmetoo/followers', 'following_url': 'https://api.github.com/users/askmetoo/following{/other_user}', 'gists_url': 'https://api.github.com/users/askmetoo/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/askmetoo/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/askmetoo/subscriptions', 'organizations_url': 'https://api.github.com/users/askmetoo/orgs', 'repos_url': 'https://api.github.com/users/askmetoo/repos', 'events_url': 'https://api.github.com/users/askmetoo/events{/privacy}', 'received_events_url': 'https://api.github.com/users/askmetoo/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'viseshrp', 'id': 11642379, 'node_id': 'MDQ6VXNlcjExNjQyMzc5', 'avatar_url': 'https://avatars.githubusercontent.com/u/11642379?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/viseshrp', 'html_url': 'https://github.com/viseshrp', 'followers_url': 'https://api.github.com/users/viseshrp/followers', 'following_url': 'https://api.github.com/users/viseshrp/following{/other_user}', 'gists_url': 'https://api.github.com/users/viseshrp/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/viseshrp/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/viseshrp/subscriptions', 'organizations_url': 'https://api.github.com/users/viseshrp/orgs', 'repos_url': 'https://api.github.com/users/viseshrp/repos', 'events_url': 'https://api.github.com/users/viseshrp/events{/privacy}', 'received_events_url': 'https://api.github.com/users/viseshrp/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'cminor102', 'id': 51357526, 'node_id': 'MDQ6VXNlcjUxMzU3NTI2', 'avatar_url': 'https://avatars.githubusercontent.com/u/51357526?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/cminor102', 'html_url': 'https://github.com/cminor102', 'followers_url': 'https://api.github.com/users/cminor102/followers', 'following_url': 'https://api.github.com/users/cminor102/following{/other_user}', 'gists_url': 'https://api.github.com/users/cminor102/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/cminor102/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/cminor102/subscriptions', 'organizations_url': 'https://api.github.com/users/cminor102/orgs', 'repos_url': 'https://api.github.com/users/cminor102/repos', 'events_url': 'https://api.github.com/users/cminor102/events{/privacy}', 'received_events_url': 'https://api.github.com/users/cminor102/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'pablosjv', 'id': 7535405, 'node_id': 'MDQ6VXNlcjc1MzU0MDU=', 'avatar_url': 'https://avatars.githubusercontent.com/u/7535405?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/pablosjv', 'html_url': 'https://github.com/pablosjv', 'followers_url': 'https://api.github.com/users/pablosjv/followers', 'following_url': 'https://api.github.com/users/pablosjv/following{/other_user}', 'gists_url': 'https://api.github.com/users/pablosjv/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/pablosjv/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/pablosjv/subscriptions', 'organizations_url': 'https://api.github.com/users/pablosjv/orgs', 'repos_url': 'https://api.github.com/users/pablosjv/repos', 'events_url': 'https://api.github.com/users/pablosjv/events{/privacy}', 'received_events_url': 'https://api.github.com/users/pablosjv/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'dakouan18', 'id': 34407054, 'node_id': 'MDQ6VXNlcjM0NDA3MDU0', 'avatar_url': 'https://avat ...
# [{'login': 'osule', 'id': 13223818, 'node_id': 'MDQ6VXNlcjEzMjIzODE4', 'avatar_url': 'https://avatars.githubusercontent.com/u/13223818?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/osule', 'html_url': 'https://github.com/osule', 'followers_url': 'https://api.github.com/users/osule/followers', 'following_url': 'https://api.github.com/users/osule/following{/other_user}', 'gists_url': 'https://api.github.com/users/osule/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/osule/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/osule/subscriptions', 'organizations_url': 'https://api.github.com/users/osule/orgs', 'repos_url': 'https://api.github.com/users/osule/repos', 'events_url': 'https://api.github.com/users/osule/events{/privacy}', 'received_events_url': 'https://api.github.com/users/osule/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'matanzed', 'id': 22625316, 'node_id': 'MDQ6VXNlcjIyNjI1MzE2', 'avatar_url': 'https://avatars.githubusercontent.com/u/22625316?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/matanzed', 'html_url': 'https://github.com/matanzed', 'followers_url': 'https://api.github.com/users/matanzed/followers', 'following_url': 'https://api.github.com/users/matanzed/following{/other_user}', 'gists_url': 'https://api.github.com/users/matanzed/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/matanzed/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/matanzed/subscriptions', 'organizations_url': 'https://api.github.com/users/matanzed/orgs', 'repos_url': 'https://api.github.com/users/matanzed/repos', 'events_url': 'https://api.github.com/users/matanzed/events{/privacy}', 'received_events_url': 'https://api.github.com/users/matanzed/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'Shaokun-X', 'id': 25054748, 'node_id': 'MDQ6VXNlcjI1MDU0NzQ4', 'avatar_url': 'https://avatars.githubusercontent.com/u/25054748?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Shaokun-X', 'html_url': 'https://github.com/Shaokun-X', 'followers_url': 'https://api.github.com/users/Shaokun-X/followers', 'following_url': 'https://api.github.com/users/Shaokun-X/following{/other_user}', 'gists_url': 'https://api.github.com/users/Shaokun-X/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Shaokun-X/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Shaokun-X/subscriptions', 'organizations_url': 'https://api.github.com/users/Shaokun-X/orgs', 'repos_url': 'https://api.github.com/users/Shaokun-X/repos', 'events_url': 'https://api.github.com/users/Shaokun-X/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Shaokun-X/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'ImamQazi', 'id': 72798097, 'node_id': 'MDQ6VXNlcjcyNzk4MDk3', 'avatar_url': 'https://avatars.githubusercontent.com/u/72798097?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ImamQazi', 'html_url': 'https://github.com/ImamQazi', 'followers_url': 'https://api.github.com/users/ImamQazi/followers', 'following_url': 'https://api.github.com/users/ImamQazi/following{/other_user}', 'gists_url': 'https://api.github.com/users/ImamQazi/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ImamQazi/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ImamQazi/subscriptions', 'organizations_url': 'https://api.github.com/users/ImamQazi/orgs', 'repos_url': 'https://api.github.com/users/ImamQazi/repos', 'events_url': 'https://api.github.com/users/ImamQazi/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ImamQazi/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'katsugeneration', 'id': 4929373, 'node_id': 'MDQ6VXNlcjQ5MjkzNzM=', 'avatar_url': 'https://avatars.githubusercontent.com/u/4 ...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-7-9b37d2b2fdbc> in <cell line: 8>()
#       6 )
#       7
# ----> 8 for page in client.paginate("repos/dlt-hub/dlt/stargazers"):
#       9     print(page)
#
# /usr/local/lib/python3.10/dist-packages/dlt/sources/helpers/rest_client/client.py in paginate(self, path, method, params, json, auth, paginator, data_selector, hooks, **kwargs)
#     222         while True:
#     223             try:
# --> 224                 response = self._send_request(request, **kwargs)
#     225             except IgnoreResponseException:
#     226                 break
#
# /usr/local/lib/python3.10/dist-packages/dlt/sources/helpers/rest_client/client.py in _send_request(self, request, **kwargs)
#     138
#     139         send_kwargs.update(**kwargs)  #  type: ignore[call-arg]
# --> 140         return self.session.send(prepared_request, **send_kwargs)
#     141
#     142     def request(self, path: str = "", method: HTTPMethod = "GET", **kwargs: Any) -> Response:
#
# /usr/local/lib/python3.10/dist-packages/tenacity/__init__.py in wrapped_f(*args, **kw)
#     334             copy = self.copy()
#     335             wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336             return copy(f, *args, **kw)
#     337
#     338         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# /usr/local/lib/python3.10/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     473         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474         while True:
# --> 475             do = self.iter(retry_state=retry_state)
#     476             if isinstance(do, DoAttempt):
#     477                 try:
#
# /usr/local/lib/python3.10/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     374         result = None
#     375         for action in self.iter_state.actions:
# --> 376             result = action(retry_state)
#     377         return result
#     378
#
# /usr/local/lib/python3.10/dist-packages/tenacity/__init__.py in <lambda>(rs)
#     396     def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     397         if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 398             self._add_action_func(lambda rs: rs.outcome.result())
#     399             return
#     400
#
# /usr/lib/python3.10/concurrent/futures/_base.py in result(self, timeout)
#     449                     raise CancelledError()
#     450                 elif self._state == FINISHED:
# --> 451                     return self.__get_result()
#     452
#     453                 self._condition.wait(timeout)
#
# /usr/lib/python3.10/concurrent/futures/_base.py in __get_result(self)
#     401         if self._exception:
#     402             try:
# --> 403                 raise self._exception
#     404             finally:
#     405                 # Break a reference cycle with the exception in self._exception
#
# /usr/local/lib/python3.10/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     476             if isinstance(do, DoAttempt):
#     477                 try:
# --> 478                     result = fn(*args, **kwargs)
#     479                 except BaseException:  # noqa: B902
#     480                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# /usr/local/lib/python3.10/dist-packages/dlt/sources/helpers/requests/session.py in send(self, request, **kwargs)
#      59     def send(self, request, **kwargs):  # type: ignore[no-untyped-def]
#      60         kwargs.setdefault("timeout", self.timeout)
# ---> 61         return super().send(request, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     708
#     709         # Response manipulation hooks
# --> 710         r = dispatch_hook("response", hooks, r, **kwargs)
#     711
#     712         # Persist cookies
#
# /usr/local/lib/python3.10/dist-packages/requests/hooks.py in dispatch_hook(key, hooks, hook_data, **kwargs)
#      28             hooks = [hooks]
#      29         for hook in hooks:
# ---> 30             _hook_data = hook(hook_data, **kwargs)
#      31             if _hook_data is not None:
#      32                 hook_data = _hook_data
#
# /usr/local/lib/python3.10/dist-packages/dlt/sources/helpers/rest_client/client.py in raise_for_status(response, *args, **kwargs)
#     313
#     314 def raise_for_status(response: Response, *args: Any, **kwargs: Any) -> None:
# --> 315     response.raise_for_status()
#     316
#     317
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1022
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#    1026     def close(self):
#
# HTTPError: 403 Client Error: rate limit exceeded for url: https://api.github.com/repositories/452221115/stargazers?page=49

# %% [markdown]
# ### **Exercise 1: Pagination with RESTClient**
# Explore the cells above and answer the question below.
# #### Question
# What type of pagination we use for GitHub API?

# %% [markdown]
# ## **Authentication**
#
# To avoid this error you can use [GitHub API Authentication](https://docs.github.com/en/rest/authentication/authenticating-to-the-rest-api?apiVersion=2022-11-28):
#
# 1. Login to your GitHub account.
# 2. Generate [API token](https://docs.github.com/en/authentication/keeping-your-account-and-data-secure/creating-a-personal-access-token) (classic one!).
# 2.  Use it as an access token for GitHub API.

# %% [markdown]
# **! ATTENTION !**
#
# Never share your credentials in public and never hard-code them in your code. Use **environment variables** or **dlt secrets.toml**.

# %% [markdown]
# Create an environment variable for your access token.
#
# ![1_5wEevNCOf80GTHwptPTB4g.webp](data:image/webp;base64,...)
#
# If you have your token [ready in Colab](https://medium.com/@parthdasawant/how-to-use-secrets-in-google-colab-450c38e3ec75), you can directly use it:

# %%
import os
from google.colab import userdata

access_token = userdata.get('SECRET_KEY')

# %% [markdown]
# So now you can use `access_token` variable in the code below:

# %%
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.auth import BearerTokenAuth


client = RESTClient(
    base_url="https://api.github.com",
    auth=BearerTokenAuth(token=access_token) # <--- put your token here
)

for page in client.paginate("repos/dlt-hub/dlt/stargazers"):
    print(page)
    break

# %% [markdown]
# So now we can rewrite our GitHub dlt pipeline using RestAPI Client and access_token.

# %%
import dlt
from dlt.sources.helpers import requests
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.auth import BearerTokenAuth


# define new resource - github stargazers
@dlt.resource
def github_stargazers():
    client = RESTClient(
        base_url="https://api.github.com",
        auth=BearerTokenAuth(token=access_token)
    )

    for page in client.paginate("repos/dlt-hub/dlt/stargazers"):
        yield page


# define new dlt pipeline
pipeline = dlt.pipeline(destination="duckdb")


# run the pipeline with the new resource
load_info = pipeline.run(github_stargazers)
print(load_info)


# explore loaded data
pipeline.dataset(dataset_type="default").github_stargazers.df()

# %% [markdown]
# You can see that all dlt [stargazers](https://github.com/dlt-hub/dlt/stargazers) were loaded into DuckDB destination.

# %% [markdown]
# ## **dlt configuration and secrets**
#
# In dlt, [configurations and secrets](https://dlthub.com/docs/general-usage/credentials/) are essential for setting up data pipelines.
#
# **Configurations** are **non-sensitive** settings that define the behavior of a data pipeline, including file paths, database hosts, timeouts, API URLs, and performance settings.
#
# On the other hand, **secrets** are **sensitive** data like passwords, API keys, and private keys, which should never be hard-coded to avoid security risks.
#
# These can be set up in various ways:
#
# * Environment variables
# * In code using `dlt.secrets` and `dlt.config`
# * Configuration files (`secrets.toml` and `config.toml`)
#
# We're gonna use `dlt.secrets.value` to define credentials in resources and sources. dlt automatically **extracts** configuration settings and secrets based on flexible naming conventions. It then **injects** these values where needed in code.
#
# **Note**: It's important to note that while you can put all configurations and credentials in the `dlt.secrets` (or `secrets.toml`) if it's more convenient, credentials cannot be placed in `dlt.config` (or `config.toml`) because dlt doesn't look for them there.

# %% [markdown]
# Let's create dlt pipeline for both endpoints `repos/dlt-hub/dlt/stargazers` and `orgs/dlt-hub/events`, we use `@dlt.source` to combine all resources in one place.

# %%
import dlt
from dlt.sources.helpers import requests
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.auth import BearerTokenAuth


@dlt.source
def github_source():
    client = RESTClient(
            base_url="https://api.github.com",
            auth=BearerTokenAuth(token=access_token)
    )

    @dlt.resource
    def github_events():
        for page in client.paginate("orgs/dlt-hub/events"):
            yield page


    @dlt.resource
    def github_stargazers():
        for page in client.paginate("repos/dlt-hub/dlt/stargazers"):
            yield page

    return github_events, github_stargazers

# %% [markdown]
# Now we're gonna use `dlt.secrets.value` in our source to enable dlt secrets configuration. Rename `access_token` variable to `secret_key` because it's already defined.

# %%
exit()

# %%
import dlt
from dlt.sources.helpers import requests
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.auth import BearerTokenAuth


@dlt.source
def github_source(access_token=dlt.secrets.value): # <--- set the secret variable "access_token" here
    client = RESTClient(
            base_url="https://api.github.com",
            auth=BearerTokenAuth(token=access_token)
    )

    @dlt.resource
    def github_events():
        for page in client.paginate("orgs/dlt-hub/events"):
            yield page


    @dlt.resource
    def github_stargazers():
        for page in client.paginate("repos/dlt-hub/dlt/stargazers"):
            yield page

    return github_events, github_stargazers

# %% [markdown]
# Configs are defined in a similar way but are accessed using `dlt.config.value`. However, since configuration variables are internally managed by `dlt`, it is unlikely that you would need to explicitly use `dlt.config.value` in most cases.

# %% [markdown]
# If you run the pipeline with `secret_key` as `dlt.secrets.value`, you will see the following error:

# %%
# define new dlt pipeline
pipeline = dlt.pipeline(destination="duckdb")


# run the pipeline with the new resource
load_info = pipeline.run(github_source())
print(load_info)

# %% [markdown]
# ^ That is what happens if you set `dlt.secrets.value` for any variable in your dlt pipeline, but don't set the secret value up.
#
# dlt is looking for secrets in following formats:
#
# ```python
# ConfigFieldMissingException: Following fields are missing: ['access_token'] in configuration with spec GithubSourceConfiguration
# 	for field "access_token" config providers and keys were tried in following order:
# 		In Environment Variables key DLT_COLAB_KERNEL_LAUNCHER__SOURCES____MAIN____GITHUB_SOURCE__ACCESS_TOKEN was not found.
# 		In Environment Variables key DLT_COLAB_KERNEL_LAUNCHER__SOURCES____MAIN____ACCESS_TOKEN was not found.
# 		In Environment Variables key DLT_COLAB_KERNEL_LAUNCHER__SOURCES__ACCESS_TOKEN was not found.
# 		In Environment Variables key DLT_COLAB_KERNEL_LAUNCHER__ACCESS_TOKEN was not found.
# 		In Environment Variables key SOURCES____MAIN____GITHUB_SOURCE__ACCESS_TOKEN was not found.
# 		In Environment Variables key SOURCES____MAIN____ACCESS_TOKEN was not found.
# 		In Environment Variables key SOURCES__ACCESS_TOKEN was not found.
# 		In Environment Variables key ACCESS_TOKEN was not found.
# WARNING: dlt looks for .dlt folder in your current working directory and your cwd (/content) is different from directory of your pipeline script (/usr/local/lib/python3.10/dist-packages).
# If you keep your secret files in the same folder as your pipeline script but run your script from some other folder, secrets/configs will not be found
# Please refer to https://dlthub.com/docs/general-usage/credentials for more information
# ```

# %% [markdown]
# To define `access_token` secret value we can use:
#
# 1. `dlt.secrets` in code (recommended for secret vaults or dynamic creds)
# 2. Environment variables (recomnended for prod)
# 3. `secrets.toml` file (recommended for local dev)

# %% [markdown]
# ### **Use `dlt.secrets` in code**
#
# You can easily rewrite your secret right in the Python code. It's especially convenient if you take credentials from third-party secret providers, or if you want to update credentials and configs dinamically.

# %%
import os
from google.colab import userdata

dlt.secrets["access_token"] = userdata.get('SECRET_KEY')

# define new dlt pipeline
pipeline = dlt.pipeline(destination="duckdb")


# run the pipeline with the new resource
load_info = pipeline.run(github_source())
print(load_info)
# Out:
# Pipeline dlt_colab_kernel_launcher load step completed in 5.32 seconds
# 2 load package(s) were loaded to destination duckdb and into dataset dlt_colab_kernel_launcher_dataset
# The duckdb destination used duckdb:////content/dlt_colab_kernel_launcher.duckdb location to store data
# Load package 1735782225.3433022 is LOADED and contains no failed jobs
# Load package 1735782250.3551035 is LOADED and contains no failed jobs

# %% [markdown]
# Alternatively you can set:
#
# ```python
# dlt.secrets["sources.access_token"] = userdata.get('SECRET_KEY')
# dlt.secrets["sources.____main____.access_token"] = userdata.get('SECRET_KEY')
# dlt.secrets["sources.____main____.github_source.access_token"] = userdata.get('SECRET_KEY')
# ...
# ```

# %% [markdown]
# * `sources` is a special word;
#
# * `__main__` is a python module name;
#
# * `github_source` is the resource name;
#
# * `access_token` is the secret variable name.
#
#
# So dlt looks for secrets according to this hierarchy:
# ```
# pipeline_name
#     |
#     |-sources
#         |
#         |-<module name>
#             |
#             |-<source function 1 name>
#                 |
#                 |- secret variable 1
#                 |- secret variable 2
# ```
#
# To keep the **naming convention** flexible, dlt looks for a lot of **possible combinations** of key names, starting from the most specific possible path. Then, if the value is not found, it removes the right-most section and tries again.

# %% [markdown]
# ### **Exercise 2: Run pipeline with `dlt.secrets.value`**
#
# Explore the cells above and answer the question below using `sql_client`.
#
# #### Question
#
# Who has id=`17202864` in the `stargazers` table? Use `sql_client`.

# %%
with pipeline.sql_client() as client:
    with client.execute_query("SELECT * FROM github_stargazers WHERE id=17202864") as table:
        print(table.df())
# Out:
#       login        id               node_id  \
# 0  rudolfix  17202864  MDQ6VXNlcjE3MjAyODY0
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/172028...
#
#                                      url                     html_url  \
# 0  https://api.github.com/users/rudolfix  https://github.com/rudolfix
#
#                                      followers_url  \
# 0  https://api.github.com/users/rudolfix/followers
#
#                                        following_url  \
# 0  https://api.github.com/users/rudolfix/followin...
#
#                                            gists_url  ...  \
# 0  https://api.github.com/users/rudolfix/gists{/g...  ...
#
#                                    subscriptions_url  \
# 0  https://api.github.com/users/rudolfix/subscrip...
#
#                             organizations_url  \
# 0  https://api.github.com/users/rudolfix/orgs
#
#                                      repos_url  \
# 0  https://api.github.com/users/rudolfix/repos
#
#                                           events_url  \
# 0  https://api.github.com/users/rudolfix/events{/...
#
#                                  received_events_url  type user_view_type  \
# 0  https://api.github.com/users/rudolfix/received...  User         public
#
#   site_admin        _dlt_load_id         _dlt_id
# 0      False  1735782225.3433022  7wgjjuC13jPwiA
#
# [1 rows x 21 columns]

# %% [markdown]
# ---
# ###  **Use environment variables**
#
# Let's set ENV in the one of the dlt formats: `ACCESS_TOKEN`.

# %%
import os
from google.colab import userdata

os.environ["ACCESS_TOKEN"] = userdata.get('SECRET_KEY')

# define new dlt pipeline
pipeline = dlt.pipeline(destination="duckdb")


# run the pipeline with the new resource
load_info = pipeline.run(github_source())
print(load_info)
# Out:
# Pipeline dlt_colab_kernel_launcher load step completed in 4.59 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset dlt_colab_kernel_launcher_dataset
# The duckdb destination used duckdb:////content/dlt_colab_kernel_launcher.duckdb location to store data
# Load package 1735782355.0124078 is LOADED and contains no failed jobs

# %% [markdown]
# Alternatively you can set:
#
# ```python
# os.environ["SOURCES__ACCESS_TOKEN"] = userdata.get('SECRET_KEY')
# os.environ["SOURCES____MAIN____ACCESS_TOKEN"] = userdata.get('SECRET_KEY')
# os.environ["SOURCES____MAIN____GITHUB_SOURCE__ACCESS_TOKEN"] = userdata.get('SECRET_KEY')
# ...
# ```

# %% [markdown]
# **How does it work?**
#
# `dlt` **automatically extracts** configuration settings and secrets based on flexible naming conventions.
#
# It then **injects** these values where needed in functions decorated with `@dlt.source`, `@dlt.resource`, or `@dlt.destination`.
#
#
# >dlt uses a specific naming hierarchy to search for the secrets and config values. This makes configurations and secrets easy to manage.
# >
# > The naming convention for **environment variables** in dlt follows a specific pattern. All names are **capitalized** and sections are separated with **double underscores** __ , e.g.  `SOURCES____MAIN____GITHUB_SOURCE__SECRET_KEY`.

# %% [markdown]
# ---
# ###  **Use dlt `secrets.toml` or `config.toml`**

# %% [markdown]
# > Please note that Colab is not well-suited for using `secrets.toml` or `config.toml` files. As a result, these sections will provide instructions rather than code cells, detailing how to use them in a local environment. You should test this functionality on your own machine. For Colab, it is recommended to use environment variables instead.

# %% [markdown]
# The `secrets.toml` file - along with the `config.toml` file - should be stored in the `.dlt` directory where your pipeline code is located:
#
# ```
# /your_project_directory
# │
# ├── .dlt
# │   ├── secrets.toml
# │   └── config.toml
# │
# └── my_pipeline.py
# ```
#
# Read more about adding [credentials](https://dlthub.com/docs/walkthroughs/add_credentials) here.

# %% [markdown]
# To set credentials via TOMLs you would first add your access token to `secrets.toml`:
#
# ```toml
# # .dlt/secrets.toml
#
# [sources]
# secret_key = "your_access_token"
# ```

# %% [markdown]
# Alternatively you can set:
#
# ```
# [sources]
# secret_key = "your_access_token"
# ```
# is equal to:
#
# ```
# secret_key = "your_access_token"
# ```
#
# and to:
#
# ```
# [sources.____main____]
# secret_key = "your_access_token"
# ```
# and to:
#
# ```
# [sources.____main____.github_source]
# secret_key = "your_access_token"
# ```

# %% [markdown]
# ### **Configure Secrets in Colab**
#
# You can configure secrets using **Secrets** sidebar. Just create a variable with the name `secrets.toml` and paste the content of the toml file from your `.dlt` folder into it. We support `config.toml` variable as well.
#
# Open **Secrets** sidebar, press "Add new secret", create variable with name `secrets.toml` and copy-paste secrets in Value field and Enable it:
#
# ```
# [sources]
# secret_key = "your_access_token"
# ```
#
#
# >dlt will not reload the secrets automatically. **Please restart your interpreter** in Colab options when you add/change content of the variables above.

# %% [markdown]
# ![Screenshot 2024-11-29 at 14.38.01.png](data:image/png;base64,...)

# %% [markdown]
# ✅ ▶ Proceed to the [next lesson](https://colab.research.google.com/drive/1mfqZulsuFDc7h27d6joe2_Dduvl1uM-2?usp=sharing)!
